# %% [markdown]
# <a href="https://colab.research.google.com/github/datactivist/scpo-data-science-bootcamp/blob/main/notebooks/2_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tabular data analysis 1 : Loading Open Food Facts data with pandas
#
# In this series of notebooks, we are going to explore the data contained in the OpenFoodFacts database.

# %% [markdown]
# ## OpenFoodFacts
#
# OpenFoodFacts is an open, crowdsourced database on food products from around the world.
#
# It is produced and managed as a digital commons.
#
# Everyone can contribute data on packaged food products: pictures, ingredients, nutritional values etc.
#
# This database has served as the foundation for many mobile phone apps, especially scanning apps to help customers while grocery shopping.

# %% [markdown]
# ### Notions
#
# * It is [*open*](https://en.wikipedia.org/wiki/Open_data): Anyone can freely use it, access it, modify it.
# * It is [*crowdsourced*](https://en.wikipedia.org/wiki/Crowdsourcing) : Anyone can add new food products to the database, complete or modify existing data.
# * It is a [knowledge commons](https://en.wikipedia.org/wiki/Knowledge_commons), a type of [digital commons](https://en.wikipedia.org/wiki/Digital_commons_(economics)).

# %% [markdown]
# ### Browsing through the dataset
#
# The OpenFoodFacts database is [available online](https://world.openfoodfacts.org/).
#
# Take a few minutes to explore the database through its online interface.
#
# * How is each product described ?
# * What types of information are provided ?

# %% [markdown]
# ### Understanding the dataset
#
# To really understand a dataset, you need to read its documentation so that you are able to answer a set of common, basic questions that will help guide your analysis, such as :
#
# * Who created this dataset and for what purpose ?
# * How was the dataset created ?
# * What do the instances that comprise the dataset represent (eg. people, companies, events, photos...) ?
# * What data does each instance consist of ? Are they "raw" data or (computed) features ?
# * Are the instances related in some way ? If so, are there specific fields that enable cross-reference ?
#
# The documentation for a dataset is always written with some purpose, for an intended type of reader, in a certain context, hence it is very likely that you will not find all the answers in the documentation.
#
# Here, you can gather partial information on OFF from :
#
# * the [presentation of the project](https://world.openfoodfacts.org/discover)
# * various pages of the [wiki](https://wiki.openfoodfacts.org/Main_Page), mostly :
#   * [Data fields](https://wiki.openfoodfacts.org/Data_fields)
#   * [Ingredients](https://wiki.openfoodfacts.org/Ingredients)
#   * [Quality](https://wiki.openfoodfacts.org/Quality)
#
# #### To go further
#
# * [Datasheets for datasets](https://arxiv.org/pdf/1803.09010.pdf) are a standardized documentation process and format proposed by AI researchers to facilitate the proper (re-)use of datasets and avoid common pitfalls in designing AI components (and ensuing scandals when they exhibit problematic biases in deployment)

# %% [markdown]
# Equipped with this new knowledge about the OpenFoodFacts database, you can start the exploratory analysis of the data to gather the missing information to complete your answers, and ask questions of your own.

# %% [markdown]
# ### OpenFoodFacts as a tabular dataset
#
# The entire set of facts about all the products in the OpenFoodFacts database can be represented as a *tabular dataset*, that is a table of data where :
#
# * each row is a product,
# * each column is a field (eg. "brand", "barcode", "energy for 100g"...),
# * each cell contains the value of a field for a product.

# %% [markdown]
# The simplest and most common format used for tabular datasets is the [CSV format](https://en.wikipedia.org/wiki/Comma-separated_values).
# CSV files can be opened in a spreadsheet software such as Microsoft Excel, Apple Numbers or LibreOffice Calc, or just any plain text editor.

# %% [markdown]
# The OpenFoodFacts database is [available for download in various formats](https://world.openfoodfacts.org/data), including the CSV format.
# Because the whole dataset is too big (the CSV export, uncompressed, weighs more than 4 GB as of 2021-08-16), we will work on a filtered subset of the dataset where we only keep products with :
#
# * a non-ambiguous barcode in the [EAN-8](https://en.wikipedia.org/wiki/EAN-8) or [EAN-13](https://en.wikipedia.org/wiki/International_Article_Number) formats ;
# * a product name,
# * brands,
# * an image URL for the product ;
# * a category ;
# * basic nutritional values.

# %% [markdown]
# ## The pandas library for tabular data analysis

# %% [markdown]
# ### Gaining functionalities with libraries
#
# The Python standard library includes a module named [csv](https://docs.python.org/3/library/csv.html#module-csv) that provides very basic support to read and write CSV files.
# This module enables you to read and write values, but nothing more.
#
# It gives you no way to :
#
# * rename columns ;
# * filter columns, eg. keep only the columns for nutritional values ;
# * filter rows, eg. select all products that are categorized as "Sweet spreads" ;
# * compute summary statistics on columns across rows, eg. compute the min, max, mean and median of fiber content per 100g ;
# * compare columns, eg. test whether they contain the same values ;
# * etc.
#
# As we saw in the 1st notebook, this can be remedied by using an additional [software library](https://en.wikipedia.org/wiki/Library_(computing)), which is, roughly speaking, a collection of code that provides functionalities to perform operations on a given task or domain .
#
# The most widely used library in Python to work on tabular datasets is [pandas](https://pandas.pydata.org/).

# %% [markdown]
# We need to import pandas and, for technical reasons, a specific pandas data type to load [categorical variables with ordered values](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#controlling-behavior).

# %%
import pandas as pd
# we need this data type for ordered categoricals
from pandas.api.types import CategoricalDtype
# lift some limitations in column width, so more cell values are displayed in full
pd.set_option('display.max_colwidth', 110)

# %% [markdown]
# The OpenFoodFacts CSV file we will load has an accompanying text file that specifies the specific data type that pandas should use for the columns. Otherwise, pandas would do its best to guess data types but its guesses are (rightfully) conservative so the result is quite rough around the edges.

# %% [markdown]
# The two files (csv and txt) are on the Google Drive of my Sciences Po account :
#
# * [CSV file](https://drive.google.com/file/d/14Pyz3Wb-FGs_9H-e7K-4Ug2X31N81Amv/view?usp=sharing)
# * [dtype txt file](https://drive.google.com/file/d/1EUBD1btT8k4PS073WLUqGm_UucUl4n3P/view?usp=sharing)
#
# 0. Check that you have saved this notebook on your Google Drive (otherwise a "Save on your Drive" button appears in the Colab notebook menu bar) ;
# 1. Download the CSV and txt files ;
# 2. Add them to the Google Drive of the account you used to open Colab : It should be your Sciences-Po account, or your personal account.
#   * To check what account you are using, click on the circle with your initial, at the top right of the Colab menu bar (as in Gmail and other Google products).
#   * Then go to <https://drive.google.com/>, check you are logged in with the same account, and drop your files where you want.
# 3. To the very left of this Colab notebook, there is a small "folder" icon. Click on it, a menu bar will appear with three icons below "Files". Click on the icon on the right (dark folder icon, with the Drive icon). It will enable you to access files on your Drive from your Colab notebook.
# 4. In the next cell, change the path to the files to match the path on your Drive.
#
# It should work, but let me know if you encounter any issue.

# %%
# this code probably appeared with the above procedure
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# dataset and data type of the columns
# - google drive
# OFF_FILE = 'drive/MyDrive/data-science-bootcamp/off_products_subset.csv'
# DTYPE_FILE = 'drive/MyDrive/data-science-bootcamp/dtype.txt'
# - local
OFF_FILE = '../data/processed/off_products_subset.csv'
DTYPE_FILE = '../data/processed/dtype.txt'

# %% [markdown]
# We will use a custom utility function, `load_off`, to load the OpenFoodFacts dataset and convert a column.
#
# You do not need to understand or even look at its code because this requires a few Python functions and technical notions (file input and output, evaluation) that we could not cover in the first notebook and are beyond the objectives of this bootcamp.
# However, feel free to ask Mathieu questions if you are curious !

# %%
def load_off():
  """Load the filtered subset of OpenFoodFacts.
  
  Returns
  -------
  df : pd.DataFrame
    (A filtered subset of the) OpenFoodFacts tabular dataset.
  """
  # load the data types for the columns
  with open(DTYPE_FILE) as f:
    dtype = eval(f.read())

  # load the dataset
  df = pd.read_csv(OFF_FILE, sep='\t', dtype=dtype)
  # convert columns with datetimes
  for col_name in ('created_datetime', 'last_modified_datetime'):
    # ISO 8601 dates
    df[col_name] = pd.to_datetime(df[col_name])
  #
  return df

# %% [markdown]
# We load the dataset using the function above.

# %%
df = load_off()

# %% [markdown]
# If all went fine, you do not see anything.
# What have we read, really ?
# You remember that typing the name of a variable, as the only (or last) line of a notebook cell, prints its value.

# %%
# type the name of the variable containing the dataset
df
# Out:
#                  code  \
# 0       0000101209159
# 1       0000159487776
# 2       0000204286484
# 3       0000250632969
# 4       0000460938714
# ...               ...
# 416547  9999091865142
# 416548       99994440
# 416549  9999900002553
# 416550  9999991149090
# 416551  9999999175305
#
#                                                                                                                   url  \
# 0       http://world-en.openfoodfacts.org/product/0000101209159/veritable-pate-a-tartiner-noisettes-chocolat-noir-...
# 1                             http://world-en.openfoodfacts.org/product/0000159487776/milkyway-magic-stars-chocolates
# 2       http://world-en.openfoodfacts.org/product/0000204286484/mehrkomponeneten-protein-90-c6-haselnuss-allfitnes...
# 3       http://world-en.openfoodfacts.org/product/0000250632969/mehrkomponeneten-protein-90-c6-banane-allfitnessfa...
# 4             http://world-en.openfoodfacts.org/product/0000460938714/100-soja-protein-haselnuss-allfitnessfactory-de
# ...                                                                                                               ...
# 416547                         http://world-en.openfoodfacts.org/product/9999091865142/paprikas-kukorica-csemege-spar
# 416548                        http://world-en.openfoodfacts.org/product/99994440/veganes-muhlenhack-rugenwalder-muhle
# 416549                      http://world-en.openfoodfacts.org/product/9999900002553/chocolat-de-couverture-noir-barry
# 416550                              http://world-en.openfoodfacts.org/product/9999991149090/riz-parfume-king-elephant
# 416551      http://world-en.openfoodfacts.org/product/9999999175305/erdbeerkuchen-1019g-tiefgefroren-coppenrath-wiese
#
#                      creator          created_datetime  \
# 0                    kiliweb 2018-02-22 10:56:57+00:00
# 1            usda-ndb-import 2017-03-09 16:01:56+00:00
# 2       allfitnessfactory-de 2016-12-30 12:12:46+00:00
# 3       allfitnessfactory-de 2017-01-13 07:30:12+00:00
# 4       allfitnessfactory-de 2016-12-30 11:39:50+00:00
# ...                      ...                       ...
# 416547                hunsly 2018-10-21 15:10:04+00:00
# 416548               kiliweb 2021-02-20 16:41:45+00:00
# 416549               kiliweb 2018-03-21 20:59:04+00:00
# 416550               kiliweb 2018-02-20 17:07:29+00:00
# 416551                   sil 2019-12-22 08:13:01+00:00
#
#           last_modified_datetime  \
# 0      2020-01-18 19:26:31+00:00
# 1      2020-04-22 20:31:56+00:00
# 2      2017-03-24 16:39:27+00:00
# 3      2017-03-24 16:42:57+00:00
# 4      2017-03-24 16:47:58+00:00
# ...                          ...
# 416547 2019-11-18 22:25:49+00:00
# 416548 2021-02-21 09:22:46+00:00
# 416549 2018-09-16 20:23:38+00:00
# 416550 2018-12-20 20:51:04+00:00
# 416551 2020-08-04 09:24:05+00:00
#
#                                              product_name  \
# 0       Véritable pâte à tartiner noisettes chocolat noir
# 1                        Milkyway, magic stars chocolates
# 2                 Mehrkomponeneten Protein 90 C6 Haselnuß
# 3                   Mehrkomponeneten Protein 90 C6 Banane
# 4                             100% Soja Protein Haselnuss
# ...                                                   ...
# 416547                          Paprikás Kukorica csemege
# 416548                                 Veganes Mühlenhack
# 416549                        Chocolat de Couverture Noir
# 416550                                        Riz parfumé
# 416551                   Erdbeerkuchen 1019g tiefgefroren
#
#                                           generic_name  quantity  \
# 0                                                 <NA>     350 g
# 1                                                 <NA>      <NA>
# 2       Mehrkomponeneten Protein in Haselnuß Geschmack    2,5 kg
# 3        Mehrkomponeneten Protein in Bananen Geschmack    2,5 kg
# 4                100% Soja Protein Haselnuss Geschmack      2 kg
# ...                                                ...       ...
# 416547                              extrudált kukorica     100 g
# 416548                                            <NA>     180 g
# 416549                                            <NA>     100 g
# 416550                                            <NA>      <NA>
# 416551                                            <NA>  1,019 kg
#
#                   packaging                brands  ... sodium_100g  \
# 0                      <NA>               Bovetti  ...       0.004
# 1                      <NA>              Milkyway  ...         NaN
# 2                    bucket  allfitnessfactory.de  ...         NaN
# 3                    bucket  allfitnessfactory.de  ...         NaN
# 4                    bucket  allfitnessfactory.de  ...         NaN
# ...                     ...                   ...  ...         ...
# 416547       műanyag,zacskó                  Spar  ...       0.384
# 416548                 <NA>     Rügenwalder Mühle  ...       0.600
# 416549                 <NA>                 Barry  ...       0.012
# 416550                 <NA>         King Elephant  ...       0.000
# 416551  Kunststoff,Styropor    Coppenrath & Wiese  ...       0.112
#
#        alcohol_100g vitamin-a_100g vitamin-c_100g vitamin-b1_100g  \
# 0               NaN            NaN            NaN             NaN
# 1               NaN            NaN            NaN             NaN
# 2               NaN            NaN            NaN             NaN
# 3               NaN            NaN            NaN             NaN
# 4               NaN            NaN            NaN             NaN
# ...             ...            ...            ...             ...
# 416547          NaN            NaN            NaN             NaN
# 416548          NaN            NaN            NaN             NaN
# 416549          NaN            NaN            NaN             NaN
# 416550          NaN            NaN            NaN             NaN
# 416551          NaN            NaN            NaN             NaN
#
#        potassium_100g calcium_100g iron_100g magnesium_100g  \
# 0                 NaN          NaN       NaN            NaN
# 1                 NaN          NaN       NaN            NaN
# 2                 NaN          NaN       NaN            NaN
# 3                 NaN          NaN       NaN            NaN
# 4                 NaN          NaN       NaN            NaN
# ...               ...          ...       ...            ...
# 416547            NaN          NaN       NaN            NaN
# 416548            NaN          NaN       NaN            NaN
# 416549            NaN          NaN       NaN            NaN
# 416550            NaN          NaN       NaN            NaN
# 416551            NaN          NaN       NaN            NaN
#
#        nutrition-score-fr_100g
# 0                         23.0
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 416547                    11.0
# 416548                    -3.0
# 416549                    22.0
# 416550                     0.0
# 416551                    12.0
#
# [416552 rows x 66 columns]

# %% [markdown]
# The dataset is loaded in a pandas DataFrame, a type of object described in the [pandas intro tutorial 01](https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html).

# %% [markdown]
# By default pandas displays the column headers, the first and last five rows with their row index, the total number of rows and columns.

# %% [markdown]
# How many rows and columns does the table contain in total ?

# %% [markdown]
# You can display the first `n` entries of a Dataframe with the DataFrame method [head](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html), and the last `n` entries with [tail](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html#pandas.DataFrame.tail).
#
# Remember that methods are attached to an object, and are called with the dot notation.

# %%
# display the first entry
df.head(1)
# Out:
#             code  \
# 0  0000101209159
#
#                                                                                                              url  \
# 0  http://world-en.openfoodfacts.org/product/0000101209159/veritable-pate-a-tartiner-noisettes-chocolat-noir-...
#
#    creator          created_datetime    last_modified_datetime  \
# 0  kiliweb 2018-02-22 10:56:57+00:00 2020-01-18 19:26:31+00:00
#
#                                         product_name generic_name quantity  \
# 0  Véritable pâte à tartiner noisettes chocolat noir         <NA>    350 g
#
#   packaging   brands  ... sodium_100g alcohol_100g vitamin-a_100g  \
# 0      <NA>  Bovetti  ...       0.004          NaN            NaN
#
#   vitamin-c_100g vitamin-b1_100g potassium_100g calcium_100g iron_100g  \
# 0            NaN             NaN            NaN          NaN       NaN
#
#   magnesium_100g nutrition-score-fr_100g
# 0            NaN                    23.0
#
# [1 rows x 66 columns]

# %% [markdown]
# Display the first 7 entries.

# %%
df.head(7)
# Out:
#             code  \
# 0  0000101209159
# 1  0000159487776
# 2  0000204286484
# 3  0000250632969
# 4  0000460938714
# 5  0000470322800
# 6  0000501050603
#
#                                                                                                              url  \
# 0  http://world-en.openfoodfacts.org/product/0000101209159/veritable-pate-a-tartiner-noisettes-chocolat-noir-...
# 1                        http://world-en.openfoodfacts.org/product/0000159487776/milkyway-magic-stars-chocolates
# 2  http://world-en.openfoodfacts.org/product/0000204286484/mehrkomponeneten-protein-90-c6-haselnuss-allfitnes...
# 3  http://world-en.openfoodfacts.org/product/0000250632969/mehrkomponeneten-protein-90-c6-banane-allfitnessfa...
# 4        http://world-en.openfoodfacts.org/product/0000460938714/100-soja-protein-haselnuss-allfitnessfactory-de
# 5    http://world-en.openfoodfacts.org/product/0000470322800/whey-protein-aus-molke-vanilla-allfitnessfactory-de
# 6  http://world-en.openfoodfacts.org/product/0000501050603/whey-protein-aus-molke-1000-gramm-vanilla-allfitne...
#
#                 creator          created_datetime    last_modified_datetime  \
# 0               kiliweb 2018-02-22 10:56:57+00:00 2020-01-18 19:26:31+00:00
# 1       usda-ndb-import 2017-03-09 16:01:56+00:00 2020-04-22 20:31:56+00:00
# 2  allfitnessfactory-de 2016-12-30 12:12:46+00:00 2017-03-24 16:39:27+00:00
# 3  allfitnessfactory-de 2017-01-13 07:30:12+00:00 2017-03-24 16:42:57+00:00
# 4  allfitnessfactory-de 2016-12-30 11:39:50+00:00 2017-03-24 16:47:58+00:00
# 5  allfitnessfactory-de 2017-01-13 10:22:12+00:00 2017-03-24 16:47:32+00:00
# 6  allfitnessfactory-de 2017-01-13 10:12:31+00:00 2017-03-24 16:44:38+00:00
#
#                                         product_name  \
# 0  Véritable pâte à tartiner noisettes chocolat noir
# 1                   Milkyway, magic stars chocolates
# 2            Mehrkomponeneten Protein 90 C6 Haselnuß
# 3              Mehrkomponeneten Protein 90 C6 Banane
# 4                        100% Soja Protein Haselnuss
# 5                     Whey Protein aus Molke Vanilla
# 6          Whey Protein aus Molke 1000 Gramm Vanilla
#
#                                           generic_name quantity packaging  \
# 0                                                 <NA>    350 g      <NA>
# 1                                                 <NA>     <NA>      <NA>
# 2       Mehrkomponeneten Protein in Haselnuß Geschmack   2,5 kg    bucket
# 3        Mehrkomponeneten Protein in Bananen Geschmack   2,5 kg    bucket
# 4                100% Soja Protein Haselnuss Geschmack     2 kg    bucket
# 5             Whey Protein aus Molke Vanille Geschmack    2000g       can
# 6  Whey Protein aus Molke 1000 Gramm Vanille Geschmack    1000g       bag
#
#                  brands  ... sodium_100g alcohol_100g vitamin-a_100g  \
# 0               Bovetti  ...    0.004000          NaN            NaN
# 1              Milkyway  ...         NaN          NaN            NaN
# 2  allfitnessfactory.de  ...         NaN          NaN            NaN
# 3  allfitnessfactory.de  ...         NaN          NaN            NaN
# 4  allfitnessfactory.de  ...         NaN          NaN            NaN
# 5  allfitnessfactory.de  ...    0.484632          NaN            NaN
# 6  allfitnessfactory.de  ...    0.484632          NaN            NaN
#
#   vitamin-c_100g vitamin-b1_100g potassium_100g calcium_100g iron_100g  \
# 0            NaN             NaN            NaN          NaN       NaN
# 1            NaN             NaN            NaN          NaN       NaN
# 2            NaN             NaN            NaN          NaN       NaN
# 3            NaN             NaN            NaN          NaN       NaN
# 4            NaN             NaN            NaN          NaN       NaN
# 5            NaN             NaN            NaN          NaN       NaN
# 6            NaN             NaN            NaN          NaN       NaN
#
#   magnesium_100g nutrition-score-fr_100g
# 0            NaN                    23.0
# 1            NaN                     NaN
# 2            NaN                     NaN
# 3            NaN                     NaN
# 4            NaN                     NaN
# 5            NaN                     NaN
# 6            NaN                     NaN
#
# [7 rows x 66 columns]

# %% [markdown]
# Display the last 3 entries.

# %%
df.tail(3)
# Out:
#                  code  \
# 416549  9999900002553
# 416550  9999991149090
# 416551  9999999175305
#
#                                                                                                               url  \
# 416549                  http://world-en.openfoodfacts.org/product/9999900002553/chocolat-de-couverture-noir-barry
# 416550                          http://world-en.openfoodfacts.org/product/9999991149090/riz-parfume-king-elephant
# 416551  http://world-en.openfoodfacts.org/product/9999999175305/erdbeerkuchen-1019g-tiefgefroren-coppenrath-wiese
#
#         creator          created_datetime    last_modified_datetime  \
# 416549  kiliweb 2018-03-21 20:59:04+00:00 2018-09-16 20:23:38+00:00
# 416550  kiliweb 2018-02-20 17:07:29+00:00 2018-12-20 20:51:04+00:00
# 416551      sil 2019-12-22 08:13:01+00:00 2020-08-04 09:24:05+00:00
#
#                             product_name generic_name  quantity  \
# 416549       Chocolat de Couverture Noir         <NA>     100 g
# 416550                       Riz parfumé         <NA>      <NA>
# 416551  Erdbeerkuchen 1019g tiefgefroren         <NA>  1,019 kg
#
#                   packaging              brands  ... sodium_100g alcohol_100g  \
# 416549                 <NA>               Barry  ...       0.012          NaN
# 416550                 <NA>       King Elephant  ...       0.000          NaN
# 416551  Kunststoff,Styropor  Coppenrath & Wiese  ...       0.112          NaN
#
#        vitamin-a_100g vitamin-c_100g vitamin-b1_100g potassium_100g  \
# 416549            NaN            NaN             NaN            NaN
# 416550            NaN            NaN             NaN            NaN
# 416551            NaN            NaN             NaN            NaN
#
#        calcium_100g iron_100g magnesium_100g nutrition-score-fr_100g
# 416549          NaN       NaN            NaN                    22.0
# 416550          NaN       NaN            NaN                     0.0
# 416551          NaN       NaN            NaN                    12.0
#
# [3 rows x 66 columns]

# %% [markdown]
# **Hint** Some URLs are longer than the maximal displayed text length for a cell (by default 80 characters, previously raised here to 110). This will make it harder for you to consult the product page on the OFF website.
# You can use the `values` attribute to get the complete array of values for a (subset of a) DataFrame, or of a column (Series).

# %%
# display the arrays of values of all fields for the first 2 products
# NB : each entry has 2 URLs : one for the product page, one for its (small-sized) image
df.head(2).values
# Out:
# array([['0000101209159',
#         'http://world-en.openfoodfacts.org/product/0000101209159/veritable-pate-a-tartiner-noisettes-chocolat-noir-bovetti',
#         'kiliweb', Timestamp('2018-02-22 10:56:57+0000', tz='UTC'),
#         Timestamp('2020-01-18 19:26:31+0000', tz='UTC'),
#         'Véritable pâte à tartiner noisettes chocolat noir', <NA>,
#         '350 g', <NA>, 'Bovetti',
#         'Spreads,Breakfasts,Sweet spreads,fr:Pâtes à tartiner,Hazelnut spreads,Chocolate spreads,Cocoa and hazelnuts spreads',
#         <NA>, <NA>, 'No gluten,No palm oil', <NA>, <NA>, <NA>, <NA>,
#         'France', <NA>, <NA>, <NA>, <NA>, nan, <NA>, <NA>, <NA>, <NA>,
#         <NA>, <NA>, <NA>, 23, 'e', nan, 'Sugary snacks', 'Sweets',
#         'To be completed,Nutrition facts completed,Ingredients to be completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Categories completed,Brands completed,Packaging to be completed,Quantity completed,Product name completed,Photos validated,Photos uploaded',
#         <NA>, 20, 'd', 'Cocoa and hazelnuts spreads',
#         'https://images.openfoodfacts.org/images/products/000/010/120/9159/front_fr.4.200.jpg',
#         nan, 617.0, 2582.0, 48.0, 10.0, nan, nan, nan, nan, 36.0, 32.0,
#         nan, 8.0, 0.01, 0.004, nan, nan, nan, nan, nan, nan, nan, nan,
#         23.0],
#        ['0000159487776',
#         'http://world-en.openfoodfacts.org/product/0000159487776/milkyway-magic-stars-chocolates',
#         'usda-ndb-import',
#         Timestamp('2017-03-09 16:01:56+0000', tz='UTC'),
#         Timestamp('2020-04-22 20:31:56+0000', tz='UTC'),
#         'Milkyway, magic stars chocolates', <NA>, <NA>, <NA>, 'Milkyway',
#         'Snacks,Sweet snacks,Cocoa and its products,Confectioneries,Chocolate candies',
#         <NA>, <NA>, <NA>, <NA>, <NA>, <NA>, <NA>, 'United States',
#         'Sugar, cocoa butter, skimmed milk powder, cocoa mass, whey powder (from milk), lactose, milk fat, emulsifier (soya lecithin), natural vanilla extract.',
#         <NA>, <NA>, '100 g (100 g)', 100.0, 1, 'en:e322,en:e322i',
#         'E322 - Lecithins,E322i - Lecithin', 0, <NA>, 0, <NA>, <NA>, nan,
#         '4', 'Sugary snacks', 'Sweets',
#         'To be completed,Nutrition facts completed,Ingredients completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Categories completed,Brands completed,Packaging to be completed,Quantity to be completed,Product name completed,Photos to be validated,Photos uploaded',
#         'MILKYWAY', <NA>, nan, 'Chocolate candies',
#         'https://images.openfoodfacts.org/images/products/000/015/948/7776/front_en.3.200.jpg',
#         nan, 557.0, 2330.0, 34.7, nan, nan, nan, nan, nan, 54.2, 53.6,
#         nan, 6.4, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#       dtype=object)

# %% [markdown]
# ### About the data table
#
# We can display a summary of the DataFrame with `info`, including for each column its index, name, number of non-null values, and data type (`dtype`).
# For more information, you can read the [pandas intro tutorial 02](https://pandas.pydata.org/docs/getting_started/intro_tutorials/02_read_write.html).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416552 entries, 0 to 416551
# Data columns (total 66 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   code                                        416552 non-null  string
#  1   url                                         416552 non-null  string
#  2   creator                                     416551 non-null  category
#  3   created_datetime                            416552 non-null  datetime64[ns, UTC]
#  4   last_modified_datetime                      416552 non-null  datetime64[ns, UTC]
#  5   product_name                                416552 non-null  string
#  6   generic_name                                99355 non-null   string
#  7   quantity                                    286295 non-null  string
#  8   packaging                                   221026 non-null  string
#  9   brands                                      416552 non-null  string
#  10  categories_en                               416544 non-null  string
#  11  origins_en                                  66661 non-null   string
#  12  manufacturing_places                        101974 non-null  string
#  13  labels_en                                   200056 non-null  string
#  14  emb_codes                                   78281 non-null   string
#  15  emb_codes_tags                              78258 non-null   string
#  16  purchase_places                             131635 non-null  string
#  17  stores                                      163962 non-null  string
#  18  countries_en                                415503 non-null  string
#  19  ingredients_text                            284310 non-null  string
#  20  allergens                                   102046 non-null  string
#  21  traces_en                                   91851 non-null   string
#  22  serving_size                                129820 non-null  string
#  23  serving_quantity                            126294 non-null  float64
#  24  additives_n                                 284311 non-null  UInt8
#  25  additives_tags                              148112 non-null  string
#  26  additives_en                                148112 non-null  string
#  27  ingredients_from_palm_oil_n                 284311 non-null  UInt8
#  28  ingredients_from_palm_oil_tags              9397 non-null    string
#  29  ingredients_that_may_be_from_palm_oil_n     284311 non-null  UInt8
#  30  ingredients_that_may_be_from_palm_oil_tags  20904 non-null   string
#  31  nutriscore_score                            348265 non-null  Int8
#  32  nutriscore_grade                            348265 non-null  category
#  33  nova_group                                  256895 non-null  category
#  34  pnns_groups_1                               416550 non-null  category
#  35  pnns_groups_2                               416552 non-null  category
#  36  states_en                                   416552 non-null  string
#  37  brand_owner                                 12689 non-null   string
#  38  ecoscore_score_fr                           267772 non-null  Int8
#  39  ecoscore_grade_fr                           267772 non-null  category
#  40  main_category_en                            416544 non-null  string
#  41  image_small_url                             416552 non-null  string
#  42  energy-kj_100g                              110910 non-null  float64
#  43  energy-kcal_100g                            341593 non-null  float64
#  44  energy_100g                                 381025 non-null  float64
#  45  fat_100g                                    380738 non-null  float64
#  46  saturated-fat_100g                          374013 non-null  float64
#  47  monounsaturated-fat_100g                    7655 non-null    float64
#  48  polyunsaturated-fat_100g                    7649 non-null    float64
#  49  trans-fat_100g                              13074 non-null   float64
#  50  cholesterol_100g                            13098 non-null   float64
#  51  carbohydrates_100g                          380710 non-null  float64
#  52  sugars_100g                                 376969 non-null  float64
#  53  fiber_100g                                  162761 non-null  float64
#  54  proteins_100g                               380802 non-null  float64
#  55  salt_100g                                   373899 non-null  float64
#  56  sodium_100g                                 373897 non-null  float64
#  57  alcohol_100g                                16515 non-null   float64
#  58  vitamin-a_100g                              11760 non-null   float64
#  59  vitamin-c_100g                              13291 non-null   float64
#  60  vitamin-b1_100g                             4485 non-null    float64
#  61  potassium_100g                              7689 non-null    float64
#  62  calcium_100g                                20654 non-null   float64
#  63  iron_100g                                   15067 non-null   float64
#  64  magnesium_100g                              4295 non-null    float64
#  65  nutrition-score-fr_100g                     348267 non-null  float64
# dtypes: Int8(2), UInt8(3), category(6), datetime64[ns, UTC](2), float64(25), string(28)
# memory usage: 181.9 MB

# %% [markdown]
# `info` also displays the memory usage of the DataFrame.

# %% [markdown]
# ### Selecting subsets
#
# One of the fundamental operations on DataFrames is to be able to filter the dataset on a certain condition, to keep only certain rows or columns.
#
# The basic operators for selection are square brackets `[]`, `loc` and `iloc`, and you can select rows or columns by their position or label, or with a conditional expression on values, see the [pandas intro tutorial 03](https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html).

# %% [markdown]
# Filter rows in `df` to keep only products with Nutri-Score 'a'.

# %%
df_nutri_a = df[df["nutriscore_grade"] == "a"]
df_nutri_a
# Out:
#                  code  \
# 17      0000870000001
# 27      0001130000007
# 32      0002000000288
# 34      0002000000714
# 94      0009300000383
# ...               ...
# 416518       99003333
# 416535       99446666
# 416536  9950014911001
# 416544  9991111111154
# 416548       99994440
#
#                                                                                                              url  \
# 17            http://world-en.openfoodfacts.org/product/0000870000001/jugo-de-hierba-de-trigo-en-polvo-saludviva
# 27                   http://world-en.openfoodfacts.org/product/0001130000007/rosa-de-mosqueta-en-polvo-saludviva
# 32                   http://world-en.openfoodfacts.org/product/0002000000288/melange-rando-les-accents-du-soleil
# 34                      http://world-en.openfoodfacts.org/product/0002000000714/yaourt-nature-brebis-la-bergerie
# 94                 http://world-en.openfoodfacts.org/product/0009300000383/hamburger-dill-chips-pickles-mt-olive
# ...                                                                                                          ...
# 416518                           http://world-en.openfoodfacts.org/product/99003333/betteraves-rouges-saint-eloi
# 416535                            http://world-en.openfoodfacts.org/product/99446666/cafe-cappuccino-dolce-gusto
# 416536            http://world-en.openfoodfacts.org/product/9950014911001/oignons-jaunes-40-60-ferme-de-l-artois
# 416544  http://world-en.openfoodfacts.org/product/9991111111154/compote-a-boire-pomme-poire-la-ferme-de-coutance
# 416548                   http://world-en.openfoodfacts.org/product/99994440/veganes-muhlenhack-rugenwalder-muhle
#
#                        creator          created_datetime  \
# 17      someonefromtheuniverse 2020-02-18 20:55:02+00:00
# 27                     kiliweb 2020-02-24 19:44:40+00:00
# 32                     kiliweb 2020-05-06 06:46:15+00:00
# 34                     kiliweb 2018-02-12 12:49:20+00:00
# 94             usda-ndb-import 2017-03-09 11:58:01+00:00
# ...                        ...                       ...
# 416518                 kiliweb 2018-08-30 18:00:12+00:00
# 416535                 kiliweb 2019-01-26 17:56:40+00:00
# 416536                 kiliweb 2018-02-04 13:32:50+00:00
# 416544                 kiliweb 2018-07-13 09:23:55+00:00
# 416548                 kiliweb 2021-02-20 16:41:45+00:00
#
#           last_modified_datetime                      product_name  \
# 17     2020-05-19 15:27:51+00:00  Jugo de Hierba de Trigo en Polvo
# 27     2021-01-01 19:46:34+00:00         Rosa de Mosqueta en polvo
# 32     2020-05-06 06:57:47+00:00                     Melange Rando
# 34     2019-03-14 10:40:02+00:00              Yaourt nature brebis
# 94     2021-03-06 09:32:42+00:00      Hamburger dill chips pickles
# ...                          ...                               ...
# 416518 2020-10-08 11:45:07+00:00                 Betteraves rouges
# 416535 2020-10-20 15:37:09+00:00                   Café cappuccino
# 416536 2019-01-08 15:31:35+00:00              Oignons jaunes 40/60
# 416544 2018-07-13 09:53:19+00:00       Compote à Boire Pomme Poire
# 416548 2021-02-21 09:22:46+00:00                Veganes Mühlenhack
#
#                generic_name quantity          packaging  \
# 17                     <NA>     100g               <NA>
# 27                     <NA>     <NA>               <NA>
# 32      Mélange Fruits Secs    125 g             Sachet
# 34                     <NA>     <NA>               <NA>
# 94                     <NA>  453.6 g  Frasco de Cristal
# ...                     ...      ...                ...
# 416518                 <NA>     <NA>               <NA>
# 416535                 <NA>     <NA>               <NA>
# 416536                 <NA>     <NA>               <NA>
# 416544                 <NA>     <NA>   carton,plastique
# 416548                 <NA>    180 g               <NA>
#
#                        brands  ... sodium_100g alcohol_100g vitamin-a_100g  \
# 17                  SaludViva  ...      0.1120          NaN            NaN
# 27                  saludviva  ...      0.0016          NaN            NaN
# 32      Les Accents du Soleil  ...      0.0170          NaN            NaN
# 34                La Bergerie  ...      0.0520          NaN            NaN
# 94                  Mt. Olive  ...      0.2900          NaN            NaN
# ...                       ...  ...         ...          ...            ...
# 416518             Saint Eloi  ...      0.0560          NaN            NaN
# 416535            Dolce Gusto  ...      0.0280          NaN            NaN
# 416536      Ferme De L'artois  ...      0.0800          NaN            NaN
# 416544   La Ferme de Coutance  ...      0.0000          NaN            NaN
# 416548      Rügenwalder Mühle  ...      0.6000          NaN            NaN
#
#        vitamin-c_100g vitamin-b1_100g potassium_100g calcium_100g iron_100g  \
# 17                NaN             NaN            NaN          NaN       NaN
# 27                NaN             NaN            NaN          NaN       NaN
# 32                NaN             NaN            NaN          NaN       NaN
# 34                NaN             NaN            NaN          NaN       NaN
# 94                NaN             NaN            NaN          NaN       NaN
# ...               ...             ...            ...          ...       ...
# 416518            NaN             NaN            NaN          NaN       NaN
# 416535            NaN             NaN            NaN          NaN       NaN
# 416536            NaN             NaN            NaN          NaN       NaN
# 416544            NaN             NaN            NaN          NaN       NaN
# 416548            NaN             NaN            NaN          NaN       NaN
#
#        magnesium_100g nutrition-score-fr_100g
# 17                NaN                    -1.0
# 27                NaN                    -2.0
# 32                NaN                    -5.0
# 34                NaN                    -3.0
# 94                NaN                    -2.0
# ...               ...                     ...
# 416518            NaN                    -1.0
# 416535            NaN                    -1.0
# 416536            NaN                   -11.0
# 416544            NaN                    -3.0
# 416548            NaN                    -3.0
#
# [56260 rows x 66 columns]

# %% [markdown]
# You should have 56260 entries.

# %% [markdown]
# Now filter rows in `df` to keep products whose quantity of sugars per 100g is higher than 20g.

# %%
df_sugar_gt20 = df[df["sugars_100g"] > 20]
df_sugar_gt20
# Out:
#                  code  \
# 0       0000101209159
# 1       0000159487776
# 12      0000790310013
# 13      0000790310020
# 15      0000800000002
# ...               ...
# 416520       99018788
# 416524  9906705312602
# 416534       99440084
# 416549  9999900002553
# 416551  9999999175305
#
#                                                                                                                   url  \
# 0       http://world-en.openfoodfacts.org/product/0000101209159/veritable-pate-a-tartiner-noisettes-chocolat-noir-...
# 1                             http://world-en.openfoodfacts.org/product/0000159487776/milkyway-magic-stars-chocolates
# 12                             http://world-en.openfoodfacts.org/product/0000790310013/sour-fruit-gummies-candy-crush
# 13                                     http://world-en.openfoodfacts.org/product/0000790310020/jelly-fish-candy-crush
# 15                          http://world-en.openfoodfacts.org/product/0000800000002/epices-a-pain-d-epices-fortwenger
# ...                                                                                                               ...
# 416520                         http://world-en.openfoodfacts.org/product/99018788/pain-d-epices-lea-nature-jardin-bio
# 416524                 http://world-en.openfoodfacts.org/product/9906705312602/digestive-go-manzana-y-avena-fontaneda
# 416534                 http://world-en.openfoodfacts.org/product/99440084/confiture-de-cerises-les-comtes-de-provence
# 416549                      http://world-en.openfoodfacts.org/product/9999900002553/chocolat-de-couverture-noir-barry
# 416551      http://world-en.openfoodfacts.org/product/9999999175305/erdbeerkuchen-1019g-tiefgefroren-coppenrath-wiese
#
#                            creator          created_datetime  \
# 0                          kiliweb 2018-02-22 10:56:57+00:00
# 1                  usda-ndb-import 2017-03-09 16:01:56+00:00
# 12                        malikele 2014-01-02 17:03:07+00:00
# 13                        malikele 2014-01-02 11:21:51+00:00
# 15                         kiliweb 2018-01-03 12:54:46+00:00
# ...                            ...                       ...
# 416520  openfoodfacts-contributors 2021-01-18 20:52:04+00:00
# 416524                     kiliweb 2019-11-15 09:42:59+00:00
# 416534                     kiliweb 2018-12-14 19:03:37+00:00
# 416549                     kiliweb 2018-03-21 20:59:04+00:00
# 416551                         sil 2019-12-22 08:13:01+00:00
#
#           last_modified_datetime  \
# 0      2020-01-18 19:26:31+00:00
# 1      2020-04-22 20:31:56+00:00
# 12     2019-10-04 20:51:08+00:00
# 13     2019-10-04 20:57:26+00:00
# 15     2019-04-03 07:28:31+00:00
# ...                          ...
# 416520 2021-05-23 09:05:43+00:00
# 416524 2019-11-15 09:46:35+00:00
# 416534 2021-05-24 07:22:54+00:00
# 416549 2018-09-16 20:23:38+00:00
# 416551 2020-08-04 09:24:05+00:00
#
#                                              product_name generic_name  \
# 0       Véritable pâte à tartiner noisettes chocolat noir         <NA>
# 1                        Milkyway, magic stars chocolates         <NA>
# 12                                     Sour Fruit Gummies         <NA>
# 13                                             Jelly Fish         <NA>
# 15                                 Épices à pain d'épices         <NA>
# ...                                                   ...          ...
# 416520                                      Pain d'épices         <NA>
# 416524                    Digestive Go! - Manzana y avena         <NA>
# 416534                               Confiture de cerises         <NA>
# 416549                        Chocolat de Couverture Noir         <NA>
# 416551                   Erdbeerkuchen 1019g tiefgefroren         <NA>
#
#         quantity            packaging                  brands  ...  \
# 0          350 g                 <NA>                 Bovetti  ...
# 1           <NA>                 <NA>                Milkyway  ...
# 12        3.5 oz              Plastik             Candy Crush  ...
# 13          3 oz              Plastik             Candy Crush  ...
# 15          <NA>                 <NA>              Fortwenger  ...
# ...          ...                  ...                     ...  ...
# 416520     300 g            plastique   Léa Nature Jardin Bio  ...
# 416524      <NA>                 <NA>               Fontaneda  ...
# 416534      <NA>                 <NA>  Les Comtes de Provence  ...
# 416549     100 g                 <NA>                   Barry  ...
# 416551  1,019 kg  Kunststoff,Styropor      Coppenrath & Wiese  ...
#
#        sodium_100g alcohol_100g vitamin-a_100g vitamin-c_100g vitamin-b1_100g  \
# 0          0.00400          NaN            NaN            NaN             NaN
# 1              NaN          NaN            NaN            NaN             NaN
# 12         0.05080          NaN            NaN            NaN             NaN
# 13         0.03048          NaN            NaN            NaN             NaN
# 15         0.04000          NaN            NaN            NaN             NaN
# ...            ...          ...            ...            ...             ...
# 416520     0.15600          NaN            NaN            NaN             NaN
# 416524     0.47600          NaN            NaN            NaN             NaN
# 416534     0.03200          NaN            NaN            NaN             NaN
# 416549     0.01200          NaN            NaN            NaN             NaN
# 416551     0.11200          NaN            NaN            NaN             NaN
#
#        potassium_100g calcium_100g iron_100g magnesium_100g  \
# 0                 NaN          NaN       NaN            NaN
# 1                 NaN          NaN       NaN            NaN
# 12                NaN          NaN       NaN            NaN
# 13                NaN          NaN       NaN            NaN
# 15                NaN          NaN       NaN            NaN
# ...               ...          ...       ...            ...
# 416520            NaN          NaN       NaN            NaN
# 416524            NaN          NaN       NaN            NaN
# 416534            NaN          NaN       NaN            NaN
# 416549            NaN          NaN       NaN            NaN
# 416551            NaN          NaN       NaN            NaN
#
#        nutrition-score-fr_100g
# 0                         23.0
# 1                          NaN
# 12                        14.0
# 13                         6.0
# 15                         NaN
# ...                        ...
# 416520                     NaN
# 416524                    20.0
# 416534                    10.0
# 416549                    22.0
# 416551                    12.0
#
# [83891 rows x 66 columns]

# %% [markdown]
# You should obtain 83891 entries.

# %% [markdown]
# Filter the dataset `df` to keep only the columns corresponding to the :
# * barcode,
# * url,
# * date of creation,
# * product name,
# * brands,
# * categories,
# * ingredients text,
# * main category,
# * Nutri-Score grade,
# * Nutri-Score score,
# * Nova group.

# %%
df_sel_cols = df[["code", "url", "created_datetime", "product_name", "brands", "categories_en", "ingredients_text", "main_category_en", "nutriscore_grade", "nutriscore_score", "nova_group"]]
df_sel_cols
# Out:
#                  code  \
# 0       0000101209159
# 1       0000159487776
# 2       0000204286484
# 3       0000250632969
# 4       0000460938714
# ...               ...
# 416547  9999091865142
# 416548       99994440
# 416549  9999900002553
# 416550  9999991149090
# 416551  9999999175305
#
#                                                                                                                   url  \
# 0       http://world-en.openfoodfacts.org/product/0000101209159/veritable-pate-a-tartiner-noisettes-chocolat-noir-...
# 1                             http://world-en.openfoodfacts.org/product/0000159487776/milkyway-magic-stars-chocolates
# 2       http://world-en.openfoodfacts.org/product/0000204286484/mehrkomponeneten-protein-90-c6-haselnuss-allfitnes...
# 3       http://world-en.openfoodfacts.org/product/0000250632969/mehrkomponeneten-protein-90-c6-banane-allfitnessfa...
# 4             http://world-en.openfoodfacts.org/product/0000460938714/100-soja-protein-haselnuss-allfitnessfactory-de
# ...                                                                                                               ...
# 416547                         http://world-en.openfoodfacts.org/product/9999091865142/paprikas-kukorica-csemege-spar
# 416548                        http://world-en.openfoodfacts.org/product/99994440/veganes-muhlenhack-rugenwalder-muhle
# 416549                      http://world-en.openfoodfacts.org/product/9999900002553/chocolat-de-couverture-noir-barry
# 416550                              http://world-en.openfoodfacts.org/product/9999991149090/riz-parfume-king-elephant
# 416551      http://world-en.openfoodfacts.org/product/9999999175305/erdbeerkuchen-1019g-tiefgefroren-coppenrath-wiese
#
#                 created_datetime  \
# 0      2018-02-22 10:56:57+00:00
# 1      2017-03-09 16:01:56+00:00
# 2      2016-12-30 12:12:46+00:00
# 3      2017-01-13 07:30:12+00:00
# 4      2016-12-30 11:39:50+00:00
# ...                          ...
# 416547 2018-10-21 15:10:04+00:00
# 416548 2021-02-20 16:41:45+00:00
# 416549 2018-03-21 20:59:04+00:00
# 416550 2018-02-20 17:07:29+00:00
# 416551 2019-12-22 08:13:01+00:00
#
#                                              product_name  \
# 0       Véritable pâte à tartiner noisettes chocolat noir
# 1                        Milkyway, magic stars chocolates
# 2                 Mehrkomponeneten Protein 90 C6 Haselnuß
# 3                   Mehrkomponeneten Protein 90 C6 Banane
# 4                             100% Soja Protein Haselnuss
# ...                                                   ...
# 416547                          Paprikás Kukorica csemege
# 416548                                 Veganes Mühlenhack
# 416549                        Chocolat de Couverture Noir
# 416550                                        Riz parfumé
# 416551                   Erdbeerkuchen 1019g tiefgefroren
#
#                       brands  \
# 0                    Bovetti
# 1                   Milkyway
# 2       allfitnessfactory.de
# 3       allfitnessfactory.de
# 4       allfitnessfactory.de
# ...                      ...
# 416547                  Spar
# 416548     Rügenwalder Mühle
# 416549                 Barry
# 416550         King Elephant
# 416551    Coppenrath & Wiese
#
#                                                                                                         categories_en  \
# 0       Spreads,Breakfasts,Sweet spreads,fr:Pâtes à tartiner,Hazelnut spreads,Chocolate spreads,Cocoa and hazelnut...
# 1                                        Snacks,Sweet snacks,Cocoa and its products,Confectioneries,Chocolate candies
# 2                                                        Dietary supplements,Bodybuilding supplements,Protein powders
# 3                                                        Dietary supplements,Bodybuilding supplements,Protein powders
# 4                                                        Dietary supplements,Bodybuilding supplements,Protein powders
# ...                                                                                                               ...
# 416547                                                                                          hu:extrudált-kukorica
# 416548                                               Plant-based foods and beverages,Plant-based foods,Meat analogues
# 416549                                          Snacks,Sweet snacks,Cocoa and its products,Chocolates,Dark chocolates
# 416550  Plant-based foods and beverages,Plant-based foods,Cereals and potatoes,Seeds,Cereals and their products,Ce...
# 416551                                                                    Biscuits and cakes,Cakes,de:tiefkühl-kuchen
#
#                                                                                                      ingredients_text  \
# 0                                                                                                                <NA>
# 1       Sugar, cocoa butter, skimmed milk powder, cocoa mass, whey powder (from milk), lactose, milk fat, emulsifi...
# 2       Proteinmischung (_Sojaprotein_, _Weizenprotein_, _Molkenprotein_, _Wheyprotein_), _Milchprotein_, _Hühnere...
# 3       Proteinmischung (_Sojaprotein_, _Weizenprotein_, _Molkenprotein_, _Wheyprotein_), _Milchprotein_, _Hühnere...
# 4                                               100% Soja-Protein-Isolat (_Soja_), Aroma, Süßstoff Natrium-Saccharin.
# ...                                                                                                               ...
# 416547  kukoricadara (79%), finomított napraforgó-étolaj, őrölt fűszerpaprika (1.2%), étkezési só, színezék (papri...
# 416548  Trinkwasser, 26% Sojaproteinkonzentrat. Branntweinessig, Rapsöl, Kochsalz, natūrliches Aroma, Gewürze, Kar...
# 416549                                                                                                           <NA>
# 416550                                                                                                           <NA>
# 416551  SAHNE (33%), Erdbeeren (12%), Zucker, WEIZENHMEHL, VOLLEI, Wasser, Invertzuckersinup, Giukose-Fruktose-Sup...
#
#                    main_category_en nutriscore_grade  nutriscore_score  \
# 0       Cocoa and hazelnuts spreads                e                23
# 1                 Chocolate candies              NaN              <NA>
# 2                   Protein powders              NaN              <NA>
# 3                   Protein powders              NaN              <NA>
# 4                   Protein powders              NaN              <NA>
# ...                             ...              ...               ...
# 416547        hu:extrudált-kukorica                d                11
# 416548               Meat analogues                a                -3
# 416549              Dark chocolates                e                22
# 416550               Aromatic rices                b                 0
# 416551           de:tiefkühl-kuchen                d                12
#
#        nova_group
# 0             NaN
# 1               4
# 2               4
# 3               4
# 4               4
# ...           ...
# 416547          4
# 416548          3
# 416549        NaN
# 416550        NaN
# 416551          4
#
# [416552 rows x 11 columns]

# %% [markdown]
# ### Making a selection into a proper DataFrame
#
# You can manipulate each of these selections as a DataFrame, but behind the scenes, they are *views* of the original DataFrame `df`.
# The *view* mechanism avoids unnecessary copies of the dataset, but it is problematic when we really want to extract a subset and perform some operations only on this subset.

# %% [markdown]
# For instance, let us select all products in `df` with sugars and fat per 100g greater than 0, and add a column with the sugars to fat ratio.

# %% [markdown]
# First, we need to define two filtering conditions and apply them jointly using the [boolean "and" `&`](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#boolean-indexing).

# %%
df_sugarsfat = df[(df["sugars_100g"] > 0) & (df["fat_100g"] > 0)]
df_sugarsfat
# Out:
#                  code  \
# 0       0000101209159
# 1       0000159487776
# 5       0000470322800
# 6       0000501050603
# 7       0000526938306
# ...               ...
# 416546  9996980313319
# 416547  9999091865142
# 416548       99994440
# 416549  9999900002553
# 416551  9999999175305
#
#                                                                                                                   url  \
# 0       http://world-en.openfoodfacts.org/product/0000101209159/veritable-pate-a-tartiner-noisettes-chocolat-noir-...
# 1                             http://world-en.openfoodfacts.org/product/0000159487776/milkyway-magic-stars-chocolates
# 5         http://world-en.openfoodfacts.org/product/0000470322800/whey-protein-aus-molke-vanilla-allfitnessfactory-de
# 6       http://world-en.openfoodfacts.org/product/0000501050603/whey-protein-aus-molke-1000-gramm-vanilla-allfitne...
# 7       http://world-en.openfoodfacts.org/product/0000526938306/whey-protein-aus-molke-500-gramm-vanilla-allfitnes...
# ...                                                                                                               ...
# 416546                                     http://world-en.openfoodfacts.org/product/9996980313319/cup-noodles-nissin
# 416547                         http://world-en.openfoodfacts.org/product/9999091865142/paprikas-kukorica-csemege-spar
# 416548                        http://world-en.openfoodfacts.org/product/99994440/veganes-muhlenhack-rugenwalder-muhle
# 416549                      http://world-en.openfoodfacts.org/product/9999900002553/chocolat-de-couverture-noir-barry
# 416551      http://world-en.openfoodfacts.org/product/9999999175305/erdbeerkuchen-1019g-tiefgefroren-coppenrath-wiese
#
#                            creator          created_datetime  \
# 0                          kiliweb 2018-02-22 10:56:57+00:00
# 1                  usda-ndb-import 2017-03-09 16:01:56+00:00
# 5             allfitnessfactory-de 2017-01-13 10:22:12+00:00
# 6             allfitnessfactory-de 2017-01-13 10:12:31+00:00
# 7             allfitnessfactory-de 2017-01-13 10:03:47+00:00
# ...                            ...                       ...
# 416546  openfoodfacts-contributors 2018-09-15 14:55:18+00:00
# 416547                      hunsly 2018-10-21 15:10:04+00:00
# 416548                     kiliweb 2021-02-20 16:41:45+00:00
# 416549                     kiliweb 2018-03-21 20:59:04+00:00
# 416551                         sil 2019-12-22 08:13:01+00:00
#
#           last_modified_datetime  \
# 0      2020-01-18 19:26:31+00:00
# 1      2020-04-22 20:31:56+00:00
# 5      2017-03-24 16:47:32+00:00
# 6      2017-03-24 16:44:38+00:00
# 7      2017-03-24 16:43:14+00:00
# ...                          ...
# 416546 2019-11-03 09:45:23+00:00
# 416547 2019-11-18 22:25:49+00:00
# 416548 2021-02-21 09:22:46+00:00
# 416549 2018-09-16 20:23:38+00:00
# 416551 2020-08-04 09:24:05+00:00
#
#                                              product_name  \
# 0       Véritable pâte à tartiner noisettes chocolat noir
# 1                        Milkyway, magic stars chocolates
# 5                          Whey Protein aus Molke Vanilla
# 6               Whey Protein aus Molke 1000 Gramm Vanilla
# 7                Whey Protein aus Molke 500 Gramm Vanilla
# ...                                                   ...
# 416546                                        cup noodles
# 416547                          Paprikás Kukorica csemege
# 416548                                 Veganes Mühlenhack
# 416549                        Chocolat de Couverture Noir
# 416551                   Erdbeerkuchen 1019g tiefgefroren
#
#                                                generic_name  quantity  \
# 0                                                      <NA>     350 g
# 1                                                      <NA>      <NA>
# 5                  Whey Protein aus Molke Vanille Geschmack     2000g
# 6       Whey Protein aus Molke 1000 Gramm Vanille Geschmack     1000g
# 7        Whey Protein aus Molke 500 Gramm Vanille Geschmack      500g
# ...                                                     ...       ...
# 416546                                                 <NA>       65g
# 416547                                   extrudált kukorica     100 g
# 416548                                                 <NA>     180 g
# 416549                                                 <NA>     100 g
# 416551                                                 <NA>  1,019 kg
#
#                   packaging                brands  ... sodium_100g  \
# 0                      <NA>               Bovetti  ...    0.004000
# 1                      <NA>              Milkyway  ...         NaN
# 5                       can  allfitnessfactory.de  ...    0.484632
# 6                       bag  allfitnessfactory.de  ...    0.484632
# 7                       bag  allfitnessfactory.de  ...    0.484632
# ...                     ...                   ...  ...         ...
# 416546            plastique                nissin  ...    0.400000
# 416547       műanyag,zacskó                  Spar  ...    0.384000
# 416548                 <NA>     Rügenwalder Mühle  ...    0.600000
# 416549                 <NA>                 Barry  ...    0.012000
# 416551  Kunststoff,Styropor    Coppenrath & Wiese  ...    0.112000
#
#        alcohol_100g vitamin-a_100g vitamin-c_100g vitamin-b1_100g  \
# 0               NaN            NaN            NaN             NaN
# 1               NaN            NaN            NaN             NaN
# 5               NaN            NaN            NaN             NaN
# 6               NaN            NaN            NaN             NaN
# 7               NaN            NaN            NaN             NaN
# ...             ...            ...            ...             ...
# 416546          0.0            NaN            NaN             NaN
# 416547          NaN            NaN            NaN             NaN
# 416548          NaN            NaN            NaN             NaN
# 416549          NaN            NaN            NaN             NaN
# 416551          NaN            NaN            NaN             NaN
#
#        potassium_100g calcium_100g iron_100g magnesium_100g  \
# 0                 NaN          NaN       NaN            NaN
# 1                 NaN          NaN       NaN            NaN
# 5                 NaN          NaN       NaN            NaN
# 6                 NaN          NaN       NaN            NaN
# 7                 NaN          NaN       NaN            NaN
# ...               ...          ...       ...            ...
# 416546            NaN          NaN       NaN            NaN
# 416547            NaN          NaN       NaN            NaN
# 416548            NaN          NaN       NaN            NaN
# 416549            NaN          NaN       NaN            NaN
# 416551            NaN          NaN       NaN            NaN
#
#        nutrition-score-fr_100g
# 0                         23.0
# 1                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# ...                        ...
# 416546                     NaN
# 416547                    11.0
# 416548                    -3.0
# 416549                    22.0
# 416551                    12.0
#
# [300142 rows x 66 columns]

# %% [markdown]
# Now, let us try to add a new column with the sugars to fat ratio.

# %%
df_sugarsfat["sugarsfat_ratio"] = df_sugarsfat["sugars_100g"] / df_sugarsfat["fat_100g"]
df_sugarsfat["sugarsfat_ratio"]
# Out:
# /home/mathieu/miniconda3/envs/scpo-bootcamp/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0         0.666667
# 1         1.544669
# 5         1.304348
# 6         1.304348
# 7         1.304348
#             ...
# 416546    0.131579
# 416547    0.062500
# 416548    0.156250
# 416549    0.573561
# 416551    3.157895
# Name: sugarsfat_ratio, Length: 300142, dtype: float64

# %% [markdown]
# The output seems fine, but it is preceded by a `SettingWithCopyWarning` that tells us we are working on a *view* when we should be working on an independent copy of the subset of the dataframe.
#
# To avoid this warning, we need to turn our selection into an independent dataframe, with the function `copy()`:

# %%
df_sugarsfat = df[(df["sugars_100g"] > 0) & (df["fat_100g"] > 0)].copy()
df_sugarsfat
# Out:
#                  code  \
# 0       0000101209159
# 1       0000159487776
# 5       0000470322800
# 6       0000501050603
# 7       0000526938306
# ...               ...
# 416546  9996980313319
# 416547  9999091865142
# 416548       99994440
# 416549  9999900002553
# 416551  9999999175305
#
#                                                                                                                   url  \
# 0       http://world-en.openfoodfacts.org/product/0000101209159/veritable-pate-a-tartiner-noisettes-chocolat-noir-...
# 1                             http://world-en.openfoodfacts.org/product/0000159487776/milkyway-magic-stars-chocolates
# 5         http://world-en.openfoodfacts.org/product/0000470322800/whey-protein-aus-molke-vanilla-allfitnessfactory-de
# 6       http://world-en.openfoodfacts.org/product/0000501050603/whey-protein-aus-molke-1000-gramm-vanilla-allfitne...
# 7       http://world-en.openfoodfacts.org/product/0000526938306/whey-protein-aus-molke-500-gramm-vanilla-allfitnes...
# ...                                                                                                               ...
# 416546                                     http://world-en.openfoodfacts.org/product/9996980313319/cup-noodles-nissin
# 416547                         http://world-en.openfoodfacts.org/product/9999091865142/paprikas-kukorica-csemege-spar
# 416548                        http://world-en.openfoodfacts.org/product/99994440/veganes-muhlenhack-rugenwalder-muhle
# 416549                      http://world-en.openfoodfacts.org/product/9999900002553/chocolat-de-couverture-noir-barry
# 416551      http://world-en.openfoodfacts.org/product/9999999175305/erdbeerkuchen-1019g-tiefgefroren-coppenrath-wiese
#
#                            creator          created_datetime  \
# 0                          kiliweb 2018-02-22 10:56:57+00:00
# 1                  usda-ndb-import 2017-03-09 16:01:56+00:00
# 5             allfitnessfactory-de 2017-01-13 10:22:12+00:00
# 6             allfitnessfactory-de 2017-01-13 10:12:31+00:00
# 7             allfitnessfactory-de 2017-01-13 10:03:47+00:00
# ...                            ...                       ...
# 416546  openfoodfacts-contributors 2018-09-15 14:55:18+00:00
# 416547                      hunsly 2018-10-21 15:10:04+00:00
# 416548                     kiliweb 2021-02-20 16:41:45+00:00
# 416549                     kiliweb 2018-03-21 20:59:04+00:00
# 416551                         sil 2019-12-22 08:13:01+00:00
#
#           last_modified_datetime  \
# 0      2020-01-18 19:26:31+00:00
# 1      2020-04-22 20:31:56+00:00
# 5      2017-03-24 16:47:32+00:00
# 6      2017-03-24 16:44:38+00:00
# 7      2017-03-24 16:43:14+00:00
# ...                          ...
# 416546 2019-11-03 09:45:23+00:00
# 416547 2019-11-18 22:25:49+00:00
# 416548 2021-02-21 09:22:46+00:00
# 416549 2018-09-16 20:23:38+00:00
# 416551 2020-08-04 09:24:05+00:00
#
#                                              product_name  \
# 0       Véritable pâte à tartiner noisettes chocolat noir
# 1                        Milkyway, magic stars chocolates
# 5                          Whey Protein aus Molke Vanilla
# 6               Whey Protein aus Molke 1000 Gramm Vanilla
# 7                Whey Protein aus Molke 500 Gramm Vanilla
# ...                                                   ...
# 416546                                        cup noodles
# 416547                          Paprikás Kukorica csemege
# 416548                                 Veganes Mühlenhack
# 416549                        Chocolat de Couverture Noir
# 416551                   Erdbeerkuchen 1019g tiefgefroren
#
#                                                generic_name  quantity  \
# 0                                                      <NA>     350 g
# 1                                                      <NA>      <NA>
# 5                  Whey Protein aus Molke Vanille Geschmack     2000g
# 6       Whey Protein aus Molke 1000 Gramm Vanille Geschmack     1000g
# 7        Whey Protein aus Molke 500 Gramm Vanille Geschmack      500g
# ...                                                     ...       ...
# 416546                                                 <NA>       65g
# 416547                                   extrudált kukorica     100 g
# 416548                                                 <NA>     180 g
# 416549                                                 <NA>     100 g
# 416551                                                 <NA>  1,019 kg
#
#                   packaging                brands  ... sodium_100g  \
# 0                      <NA>               Bovetti  ...    0.004000
# 1                      <NA>              Milkyway  ...         NaN
# 5                       can  allfitnessfactory.de  ...    0.484632
# 6                       bag  allfitnessfactory.de  ...    0.484632
# 7                       bag  allfitnessfactory.de  ...    0.484632
# ...                     ...                   ...  ...         ...
# 416546            plastique                nissin  ...    0.400000
# 416547       műanyag,zacskó                  Spar  ...    0.384000
# 416548                 <NA>     Rügenwalder Mühle  ...    0.600000
# 416549                 <NA>                 Barry  ...    0.012000
# 416551  Kunststoff,Styropor    Coppenrath & Wiese  ...    0.112000
#
#        alcohol_100g vitamin-a_100g vitamin-c_100g vitamin-b1_100g  \
# 0               NaN            NaN            NaN             NaN
# 1               NaN            NaN            NaN             NaN
# 5               NaN            NaN            NaN             NaN
# 6               NaN            NaN            NaN             NaN
# 7               NaN            NaN            NaN             NaN
# ...             ...            ...            ...             ...
# 416546          0.0            NaN            NaN             NaN
# 416547          NaN            NaN            NaN             NaN
# 416548          NaN            NaN            NaN             NaN
# 416549          NaN            NaN            NaN             NaN
# 416551          NaN            NaN            NaN             NaN
#
#        potassium_100g calcium_100g iron_100g magnesium_100g  \
# 0                 NaN          NaN       NaN            NaN
# 1                 NaN          NaN       NaN            NaN
# 5                 NaN          NaN       NaN            NaN
# 6                 NaN          NaN       NaN            NaN
# 7                 NaN          NaN       NaN            NaN
# ...               ...          ...       ...            ...
# 416546            NaN          NaN       NaN            NaN
# 416547            NaN          NaN       NaN            NaN
# 416548            NaN          NaN       NaN            NaN
# 416549            NaN          NaN       NaN            NaN
# 416551            NaN          NaN       NaN            NaN
#
#        nutrition-score-fr_100g
# 0                         23.0
# 1                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# ...                        ...
# 416546                     NaN
# 416547                    11.0
# 416548                    -3.0
# 416549                    22.0
# 416551                    12.0
#
# [300142 rows x 66 columns]

# %% [markdown]
# The selection is the same as before.

# %%
df_sugarsfat["sugarsfat_ratio"] = df_sugarsfat["sugars_100g"] / df_sugarsfat["fat_100g"]
df_sugarsfat["sugarsfat_ratio"]
# Out:
# 0         0.666667
# 1         1.544669
# 5         1.304348
# 6         1.304348
# 7         1.304348
#             ...
# 416546    0.131579
# 416547    0.062500
# 416548    0.156250
# 416549    0.573561
# 416551    3.157895
# Name: sugarsfat_ratio, Length: 300142, dtype: float64

# %% [markdown]
# The ratios are the same, but we got rid of the big warning, so we must be doing things the *right* way.
#
# We will not go further and we certainly do not expect you to master the [difference between a view and a copy](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy), but at least now you know that if you encounter the big scary warning, you probably need to `copy()` your selection of rows.

# %% [markdown]
# ### Renaming columns
#
# Column names are not always ideal, either because they are not transparent (it is hard for you or an external user to understand what they stand for) or because they would look bad if they were used directly to label the axes of a datavisualization.
#
# pandas provides means to rename columns, see the [pandas intro tutorial 05](https://pandas.pydata.org/docs/getting_started/intro_tutorials/05_add_columns.html).
#
# Rename all the columns ending with `_en` (code for English) to drop this suffix, eg. `main_category_en` to `main_category`.

# %%
# select the column names that end with _en
cols_en = [x for x in df.columns if x.endswith("_en")]
cols_en
# Out:
# ['categories_en',
#  'origins_en',
#  'labels_en',
#  'countries_en',
#  'traces_en',
#  'additives_en',
#  'states_en',
#  'main_category_en']

# %%
df_ren_en = df.rename(
    columns={
        "categories_en": "categories",
        "origins_en": "origins",
        "labels_en": "labels",
        "countries_en": "countries",
        "traces_en": "traces",
        "additives_en": "additives",
        "states_en": "states",
        "main_category_en": "main_category"
    }
)
df_ren_en.columns
# Out:
# Index(['code', 'url', 'creator', 'created_datetime', 'last_modified_datetime',
#        'product_name', 'generic_name', 'quantity', 'packaging', 'brands',
#        'categories', 'origins', 'manufacturing_places', 'labels', 'emb_codes',
#        'emb_codes_tags', 'purchase_places', 'stores', 'countries',
#        'ingredients_text', 'allergens', 'traces', 'serving_size',
#        'serving_quantity', 'additives_n', 'additives_tags', 'additives',
#        'ingredients_from_palm_oil_n', 'ingredients_from_palm_oil_tags',
#        'ingredients_that_may_be_from_palm_oil_n',
#        'ingredients_that_may_be_from_palm_oil_tags', 'nutriscore_score',
#        'nutriscore_grade', 'nova_group', 'pnns_groups_1', 'pnns_groups_2',
#        'states', 'brand_owner', 'ecoscore_score_fr', 'ecoscore_grade_fr',
#        'main_category', 'image_small_url', 'energy-kj_100g',
#        'energy-kcal_100g', 'energy_100g', 'fat_100g', 'saturated-fat_100g',
#        'monounsaturated-fat_100g', 'polyunsaturated-fat_100g',
#        'trans-fat_100g', 'cholesterol_100g', 'carbohydrates_100g',
#        'sugars_100g', 'fiber_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g', 'alcohol_100g', 'vitamin-a_100g', 'vitamin-c_100g',
#        'vitamin-b1_100g', 'potassium_100g', 'calcium_100g', 'iron_100g',
#        'magnesium_100g', 'nutrition-score-fr_100g'],
#       dtype='object')

# %%
# alternative, shorter but more advanced
df_ren_en_bis = df.rename(
    columns={x: x[:-3] for x in df.columns if x.endswith("_en")}
)
df_ren_en_bis.columns
# Out:
# Index(['code', 'url', 'creator', 'created_datetime', 'last_modified_datetime',
#        'product_name', 'generic_name', 'quantity', 'packaging', 'brands',
#        'categories', 'origins', 'manufacturing_places', 'labels', 'emb_codes',
#        'emb_codes_tags', 'purchase_places', 'stores', 'countries',
#        'ingredients_text', 'allergens', 'traces', 'serving_size',
#        'serving_quantity', 'additives_n', 'additives_tags', 'additives',
#        'ingredients_from_palm_oil_n', 'ingredients_from_palm_oil_tags',
#        'ingredients_that_may_be_from_palm_oil_n',
#        'ingredients_that_may_be_from_palm_oil_tags', 'nutriscore_score',
#        'nutriscore_grade', 'nova_group', 'pnns_groups_1', 'pnns_groups_2',
#        'states', 'brand_owner', 'ecoscore_score_fr', 'ecoscore_grade_fr',
#        'main_category', 'image_small_url', 'energy-kj_100g',
#        'energy-kcal_100g', 'energy_100g', 'fat_100g', 'saturated-fat_100g',
#        'monounsaturated-fat_100g', 'polyunsaturated-fat_100g',
#        'trans-fat_100g', 'cholesterol_100g', 'carbohydrates_100g',
#        'sugars_100g', 'fiber_100g', 'proteins_100g', 'salt_100g',
#        'sodium_100g', 'alcohol_100g', 'vitamin-a_100g', 'vitamin-c_100g',
#        'vitamin-b1_100g', 'potassium_100g', 'calcium_100g', 'iron_100g',
#        'magnesium_100g', 'nutrition-score-fr_100g'],
#       dtype='object')

# %% [markdown]
# ### Summary statistics
#
# You can compute various summary statistics that depend on the type of variable in each column, see the [pandas intro tutorial 06](https://pandas.pydata.org/docs/getting_started/intro_tutorials/06_calculate_statistics.html).
#
# Compute summary statistics for several columns from different types, and combinations of columns that could provide interesting insights.
#
# For instance, compute the means of the nutritional values for :
# * fat,
# * saturated fat,
# * sugars,
# * salt.

# %%
# compute the means
df[["fat_100g", "saturated-fat_100g", "sugars_100g", "salt_100g"]].mean()
# Out:
# fat_100g              14.184523
# saturated-fat_100g     5.331667
# sugars_100g           12.815801
# salt_100g              1.500613
# dtype: float64

# %% [markdown]
# ### Computing on columns
#
# You can manipulate columns in various ways, including with operations that apply element-wise as we saw for NumPy arrays in the first notebook.
#
# You can for instance subtract the mean value of a column to each value.

# %%
# subtract to each value for 'fat' the mean value of fat in the dataset
df['fat_100g'] - df['fat_100g'].mean()
# Out:
# 0         33.815477
# 1         20.515477
# 2        -13.184523
# 3        -13.184523
# 4        -13.684523
#             ...
# 416547     9.815477
# 416548   -10.984523
# 416549    32.715477
# 416550   -13.684523
# 416551    -6.584523
# Name: fat_100g, Length: 416552, dtype: float64

# %% [markdown]
# ### Sorting data
#
# The entries are sorted by barcode.
# We might find it easier to understand the dataset if we sort entries by another criterion.

# %% [markdown]
# Sort entries by brand, following the [pandas intro tutorial 07](https://pandas.pydata.org/docs/getting_started/intro_tutorials/07_reshape_table_layout.html).

# %%
df_sort_brands = df.sort_values(by="brands")
df_sort_brands
# Out:
#                  code  \
# 902     0013562302239
# 26587   0856463002002
# 6656    0043182000703
# 15481   0099482443436
# 22953   0708953602011
# ...               ...
# 406604  8803560000143
# 406573  8801117536916
# 406609  8805713304023
# 13996   0079200009373
# 29025        14480799
#
#                                                                                                                   url  \
# 902     http://world-en.openfoodfacts.org/product/0013562302239/annie-s-whole-wheat-bunnies-baked-snack-crackers-m...
# 26587            http://world-en.openfoodfacts.org/product/0856463002002/core-meal-hearty-oatmeal-to-go-almond-raisin
# 6656                  http://world-en.openfoodfacts.org/product/0043182000703/organic-mashed-potatoes-edward-and-sons
# 15481   http://world-en.openfoodfacts.org/product/0099482443436/engine-2-plant-strong-rip-s-big-bowl-triple-berry-...
# 22953                http://world-en.openfoodfacts.org/product/0708953602011/organic-forbidden-rice-ramen-lotus-foods
# ...                                                                                                               ...
# 406604                  http://world-en.openfoodfacts.org/product/8803560000143/%EC%8C%80%EB%96%A1-%EC%86%A1%ED%95%99
# 406573  http://world-en.openfoodfacts.org/product/8801117536916/%EC%98%A4%EB%9C%A8-%ED%94%84%EB%A1%9C%EB%A7%88%EC%...
# 406609  http://world-en.openfoodfacts.org/product/8805713304023/%ED%95%9C%EC%82%B4%EB%A6%BC-%ED%98%B8%EB%B0%95%EC%...
# 13996            http://world-en.openfoodfacts.org/product/0079200009373/fun-dip-%F0%9F%A4%A9%F0%9F%A4%A9%F0%9F%A4%A9
# 29025                                                 http://world-en.openfoodfacts.org/product/14480799/%F0%9F%A4%AC
#
#                            creator          created_datetime  \
# 902                           bori 2015-07-02 01:42:07+00:00
# 26587                         bori 2015-07-02 02:56:19+00:00
# 6656                          bori 2015-07-07 02:49:56+00:00
# 15481                         bori 2015-07-02 03:07:41+00:00
# 22953                         bori 2015-07-07 02:52:46+00:00
# ...                            ...                       ...
# 406604                  woshilapin 2015-04-26 11:07:11+00:00
# 406573                       chemy 2016-07-04 01:55:08+00:00
# 406609  openfoodfacts-contributors 2020-05-21 02:10:46+00:00
# 13996             halal-app-chakib 2021-03-29 01:33:04+00:00
# 29025   openfoodfacts-contributors 2020-12-07 18:45:18+00:00
#
#           last_modified_datetime  \
# 902    2021-02-02 20:00:45+00:00
# 26587  2020-04-22 19:33:53+00:00
# 6656   2020-04-22 16:59:09+00:00
# 15481  2020-04-22 16:42:19+00:00
# 22953  2020-04-22 16:22:40+00:00
# ...                          ...
# 406604 2018-05-29 08:30:13+00:00
# 406573 2017-11-17 06:00:01+00:00
# 406609 2020-05-21 02:15:13+00:00
# 13996  2021-04-25 20:18:29+00:00
# 29025  2020-12-07 18:47:16+00:00
#
#                                                                      product_name  \
# 902     Annie's Whole Wheat Bunnies Baked Snack Crackers, Made with Organic Wheat
# 26587                             Core, meal, hearty oatmeal to go, almond raisin
# 6656                                                      Organic Mashed Potatoes
# 15481                  Engine 2, plant-strong, rip's big bowl triple berry walnut
# 22953                                                Organic Forbidden Rice Ramen
# ...                                                                           ...
# 406604                                                                         쌀떡
# 406573                                                                    오뜨 프로마즈
# 406609                                                                   한살림 호박쌀엿
# 13996                                                                     Fun dip
# 29025                                                                           🤬
#
#        generic_name    quantity         packaging  \
# 902            <NA>  7 servings              <NA>
# 26587          <NA>   1 serving              <NA>
# 6656           <NA>           4              <NA>
# 15481          <NA>           7              <NA>
# 22953          <NA>           8              <NA>
# ...             ...         ...               ...
# 406604         <NA>       500 g  Sachet,Plastique
# 406573         <NA>        240g               box
# 406609         <NA>        100g           plastic
# 13996          <NA>        <NA>           ksiskek
# 29025          <NA>           🤬                 🤬
#
#                                  brands  ... sodium_100g alcohol_100g  \
# 902                             Annie's  ...     0.83300          NaN
# 26587            Core Meal, Core Method  ...     0.02400          NaN
# 6656     Edward and Sons, Edward & Sons  ...     0.72000          NaN
# 15481                          Engine 2  ...     0.09100          NaN
# 22953                       Lotus Foods  ...     0.00000          NaN
# ...                                 ...  ...         ...          ...
# 406604                               송학  ...     0.07112          NaN
# 406573                              오리온  ...         NaN          NaN
# 406609                              한살림  ...     2.33680          NaN
# 13996                               🤩🤩🤩  ...     0.00000          NaN
# 29025                                 🤬  ...    40.00000        100.0
#
#        vitamin-a_100g vitamin-c_100g vitamin-b1_100g potassium_100g  \
# 902               0.0         0.0000             NaN            NaN
# 26587             0.0         0.0000             NaN            NaN
# 6656              0.0         0.0720             NaN            NaN
# 15481             0.0         0.0109             NaN            NaN
# 22953             0.0         0.0000             NaN            0.4
# ...               ...            ...             ...            ...
# 406604            NaN            NaN             NaN            NaN
# 406573            NaN            NaN             NaN            NaN
# 406609            NaN            NaN             NaN            NaN
# 13996             NaN            NaN             NaN            NaN
# 29025             NaN            NaN             NaN            NaN
#
#        calcium_100g iron_100g magnesium_100g nutrition-score-fr_100g
# 902           0.000   0.00120            NaN                    10.0
# 26587         0.118   0.00212            NaN                    -2.0
# 6656          0.000   0.00000            NaN                     6.0
# 15481         0.036   0.00327            NaN                    -5.0
# 22953         0.000   0.00103            NaN                    -4.0
# ...             ...       ...            ...                     ...
# 406604          NaN       NaN            NaN                    -4.0
# 406573          NaN       NaN            NaN                     NaN
# 406609          NaN       NaN            NaN                    10.0
# 13996           NaN       NaN            NaN                    14.0
# 29025           NaN       NaN            NaN                    25.0
#
# [416552 rows x 66 columns]

# %% [markdown]
# Let us look at the first entries, when sorted by brands.

# %%
df_sort_brands["brands"].head(20)
# Out:
# 902                               Annie's
# 26587              Core Meal, Core Method
# 6656       Edward and Sons, Edward & Sons
# 15481                            Engine 2
# 22953                         Lotus Foods
# 294010                               ifri
# 51329               le verger des fruits
# 227880                              !NARA
# 242806                       #männerglück
# 243671                             #sinob
# 243674                             #sinob
# 243675                             #sinob
# 243672                             #sinob
# 243679                             #sinob
# 243676                             #sinob
# 243680                             #sinob
# 243681          #sinob core,BlackLine 2.0
# 31415                        &all,アンド・オール
# 254153                &quot;Fruttis&quot;
# 210407      &quot;LB Bulgaricum&quot; PLC
# Name: brands, dtype: string

# %% [markdown]
# Oddly, only the first few lines have brand names that start with a letter, then brand names start with a special character (`!` or `#`).
# This is unexpected, because special characters should appear first.
#
# What happened here ? Let us have a better look at the *values* in `brands`.

# %%
df_sort_brands["brands"].head(20).values
# Out:
# <StringArray>
# [                       " Annie's",         ' Core Meal, Core Method',
#  ' Edward and Sons, Edward & Sons',                       ' Engine 2',
#                     ' Lotus Foods',                           ' ifri',
#           ' le verger des fruits ',                           '!NARA',
#                     '#männerglück',                          '#sinob',
#                           '#sinob',                          '#sinob',
#                           '#sinob',                          '#sinob',
#                           '#sinob',                          '#sinob',
#        '#sinob core,BlackLine 2.0',                    '&all,アンド・オール',
#              '&quot;Fruttis&quot;',   '&quot;LB Bulgaricum&quot; PLC']
# Length: 20, dtype: string

# %% [markdown]
# In the first entries, the `brands` value starts with a whitespace.
# This explains why they were sorted before the entries whose `brands` start with a special character.
#
# Brand names rarely (if ever) start with a whitespace, hence we can assume that whoever added these products made a typing error.

# %% [markdown]
# ⚠ Datasets contain all sorts of errors and oddities. Datasets released by public agencies or big actors are usually cleaner than crowdsourced datasets, but you should always be cautious.

# %% [markdown]
# To confirm our hypothesis and check whether the entries are properly sorted, we can use `iloc` to retrieve entries at arbitary positions in the DataFrame.
#
# For instance, let us check the entries ranked 4881 to 4899 (or 4900 excluded).

# %%
df_sort_brands["brands"].iloc[4881:4900]
# Out:
# 373175                   Alba
# 373169                   Alba
# 373170                   Alba
# 373171                   Alba
# 373172                   Alba
# 373163                   Alba
# 373173                   Alba
# 373166                   Alba
# 373158                   Alba
# 373162                   Alba
# 373155                   Alba
# 373161                   Alba
# 373160                   Alba
# 373157                   Alba
# 336666    Alba torri e sapori
# 6933                 Albacore
# 172373               Albacore
# 291490               Albalact
# 291497               Albalact
# Name: brands, dtype: string

# %% [markdown]
# The sorted brands are `Alba`, `Alba torri e sapori`, `Albacore` then `Albalact`, which is what we were expecting.

# %% [markdown]
# Sort entries by the Nutri-Score grade.

# %%
df_sort_nsgrade = df.sort_values(by="nutriscore_grade")
df_sort_nsgrade
# Out:
#                  code  \
# 160032  3560070446292
# 119262  3289131100095
# 49765   3038359001512
# 49766   3038359001567
# 119264  3289131217120
# ...               ...
# 416537  9955100109478
# 416539  9961193410131
# 416541       99885434
# 416545       99911522
# 416546  9996980313319
#
#                                                                                                              url  \
# 160032                               http://world-en.openfoodfacts.org/product/3560070446292/mais-doux-carrefour
# 119262                       http://world-en.openfoodfacts.org/product/3289131100095/ananas-en-morceaux-la-pulpe
# 49765              http://world-en.openfoodfacts.org/product/3038359001512/penne-rigate-offre-economique-panzani
# 49766           http://world-en.openfoodfacts.org/product/3038359001567/le-risotto-a-poeler-champignons-lustucru
# 119264  http://world-en.openfoodfacts.org/product/3289131217120/segments-de-pamplemousse-au-sirop-leger-la-pulpe
# ...                                                                                                          ...
# 416537                     http://world-en.openfoodfacts.org/product/9955100109478/cube-mendiants-maison-gaucher
# 416539                    http://world-en.openfoodfacts.org/product/9961193410131/minced-pork-avatar-meat-avatar
# 416541                   http://world-en.openfoodfacts.org/product/99885434/raviolis-pekinois-surgeles-asia-food
# 416545                                      http://world-en.openfoodfacts.org/product/99911522/chipolatas-casino
# 416546                                http://world-en.openfoodfacts.org/product/9996980313319/cup-noodles-nissin
#
#                            creator          created_datetime  \
# 160032                   carrefour 2019-01-27 18:33:45+00:00
# 119262                     kiliweb 2018-02-13 09:13:43+00:00
# 49765              date-limite-app 2015-02-28 17:49:42+00:00
# 49766   openfoodfacts-contributors 2015-03-03 17:11:18+00:00
# 119264                     kiliweb 2018-10-21 12:11:10+00:00
# ...                            ...                       ...
# 416537                     serayet 2018-12-07 20:43:21+00:00
# 416539  openfoodfacts-contributors 2021-07-27 16:42:36+00:00
# 416541  openfoodfacts-contributors 2019-07-08 10:52:02+00:00
# 416545                     alm1412 2021-07-04 10:30:44+00:00
# 416546  openfoodfacts-contributors 2018-09-15 14:55:18+00:00
#
#           last_modified_datetime                             product_name  \
# 160032 2021-03-28 20:08:55+00:00                                Mais doux
# 119262 2021-03-14 08:33:39+00:00                       Ananas en morceaux
# 49765  2021-02-23 00:17:29+00:00          Penne Rigate (offre économique)
# 49766  2020-09-06 06:19:52+00:00          Le Risotto à Poêler Champignons
# 119264 2019-01-09 11:03:28+00:00  Segments de pamplemousse au sirop léger
# ...                          ...                                      ...
# 416537 2018-12-07 20:55:16+00:00                           cube mendiants
# 416539 2021-07-27 17:14:13+00:00                       Minced Pork Avatar
# 416541 2019-07-18 07:28:24+00:00               raviolis pekinois surgelés
# 416545 2021-07-04 10:41:08+00:00                               Chipolatas
# 416546 2019-11-03 09:45:23+00:00                              cup noodles
#
#                            generic_name quantity         packaging  \
# 160032    Mais doux en grains sous vide    600 g              <NA>
# 119262                             <NA>     <NA>              <NA>
# 49765   Penne Rigate (offre économique)    500 g  sachet,plastique
# 49766                              <NA>    350 g         Plastique
# 119264                             <NA>     <NA>              <NA>
# ...                                 ...      ...               ...
# 416537                             <NA>    200 g    cube plastique
# 416539                             <NA>     240g     Plastic,paper
# 416541                             <NA>   3800 g              <NA>
# 416545                             <NA>        6         barquette
# 416546                             <NA>      65g         plastique
#
#                 brands  ... sodium_100g alcohol_100g vitamin-a_100g  \
# 160032       Carrefour  ...     0.21200          NaN            NaN
# 119262        La Pulpe  ...     0.00000          NaN            NaN
# 49765          Panzani  ...     0.00520          NaN            NaN
# 49766         Lustucru  ...     0.03200          NaN            NaN
# 119264        La Pulpe  ...     0.00400          NaN            NaN
# ...                ...  ...         ...          ...            ...
# 416537  maison Gaucher  ...         NaN          NaN            NaN
# 416539     Meat Avatar  ...         NaN          NaN            NaN
# 416541       asia food  ...     0.41656          NaN            NaN
# 416545          Casino  ...         NaN          NaN            NaN
# 416546          nissin  ...     0.40000          0.0            NaN
#
#        vitamin-c_100g vitamin-b1_100g potassium_100g calcium_100g iron_100g  \
# 160032            NaN             NaN            NaN          NaN       NaN
# 119262            NaN             NaN            NaN          NaN       NaN
# 49765             NaN             NaN            NaN          NaN       NaN
# 49766             NaN             NaN            NaN          NaN       NaN
# 119264            NaN             NaN            NaN          NaN       NaN
# ...               ...             ...            ...          ...       ...
# 416537            NaN             NaN            NaN          NaN       NaN
# 416539            NaN             NaN            NaN          NaN       NaN
# 416541            NaN             NaN            NaN          NaN       NaN
# 416545            NaN             NaN            NaN          NaN       NaN
# 416546            NaN             NaN            NaN          NaN       NaN
#
#        magnesium_100g nutrition-score-fr_100g
# 160032            NaN                    -1.0
# 119262            NaN                    -3.0
# 49765             NaN                    -4.0
# 49766             NaN                    -1.0
# 119264            NaN                    -2.0
# ...               ...                     ...
# 416537            NaN                     NaN
# 416539            NaN                     NaN
# 416541            NaN                     NaN
# 416545            NaN                     NaN
# 416546            NaN                     NaN
#
# [416552 rows x 66 columns]

# %% [markdown]
# Let us check the first 20 entries.

# %%
df_sort_nsgrade["nutriscore_grade"].head(20)
# Out:
# 160032    a
# 119262    a
# 49765     a
# 49766     a
# 119264    a
# 119265    a
# 386381    a
# 325358    a
# 49772     a
# 49773     a
# 49774     a
# 49776     a
# 386380    a
# 49779     a
# 49780     a
# 49781     a
# 49782     a
# 49783     a
# 49784     a
# 49785     a
# Name: nutriscore_grade, dtype: category
# Categories (5, object): ['a' < 'b' < 'c' < 'd' < 'e']

# %% [markdown]
# The entries with nutriscore grade 'a' are ranked first, as expected.

# %% [markdown]
# Sort entries by the Nutri-Score grade and Nova group (together).

# %%
df_sort_nsgrade_novagroup = df.sort_values(by=["nutriscore_grade", "nova_group"])
df_sort_nsgrade_novagroup
# Out:
#                  code  \
# 32      0002000000288
# 185     0010200231005
# 186     0010248765135
# 190     0010300343257
# 253     0011110043573
# ...               ...
# 416520       99018788
# 416522       99020118
# 416523  9906410000009
# 416528       99272104
# 416546  9996980313319
#
#                                                                                                                   url  \
# 32                        http://world-en.openfoodfacts.org/product/0002000000288/melange-rando-les-accents-du-soleil
# 185     http://world-en.openfoodfacts.org/product/0010200231005/old-fashioned-stone-ground-yellow-corn-meal-wilkin...
# 186                                   http://world-en.openfoodfacts.org/product/0010248765135/yemina-semilla-de-melon
# 190                                   http://world-en.openfoodfacts.org/product/0010300343257/natural-almonds-emerald
# 253                                  http://world-en.openfoodfacts.org/product/0011110043573/raw-almonds-simple-truth
# ...                                                                                                               ...
# 416520                         http://world-en.openfoodfacts.org/product/99018788/pain-d-epices-lea-nature-jardin-bio
# 416522                               http://world-en.openfoodfacts.org/product/99020118/pelardon-delices-des-cevennes
# 416523                                http://world-en.openfoodfacts.org/product/9906410000009/roussette-du-bugey-2011
# 416528                               http://world-en.openfoodfacts.org/product/99272104/casa-mayor-frutos-secos-damel
# 416546                                     http://world-en.openfoodfacts.org/product/9996980313319/cup-noodles-nissin
#
#                            creator          created_datetime  \
# 32                         kiliweb 2020-05-06 06:46:15+00:00
# 185                usda-ndb-import 2017-03-09 12:09:40+00:00
# 186               openfoodfactsmx4 2018-11-09 19:59:29+00:00
# 190                usda-ndb-import 2017-03-09 12:44:57+00:00
# 253                        kiliweb 2020-03-02 14:17:15+00:00
# ...                            ...                       ...
# 416520  openfoodfacts-contributors 2021-01-18 20:52:04+00:00
# 416522  openfoodfacts-contributors 2018-10-01 10:52:20+00:00
# 416523                  agamitsudo 2013-07-10 18:20:08+00:00
# 416528  openfoodfacts-contributors 2021-05-03 05:28:52+00:00
# 416546  openfoodfacts-contributors 2018-09-15 14:55:18+00:00
#
#           last_modified_datetime                                 product_name  \
# 32     2020-05-06 06:57:47+00:00                                Melange Rando
# 185    2020-07-13 03:01:35+00:00  Old Fashioned Stone Ground Yellow Corn Meal
# 186    2018-11-09 20:05:37+00:00                      Yemina Semilla de melón
# 190    2020-04-22 18:05:35+00:00                              Natural Almonds
# 253    2020-04-23 21:07:06+00:00                                  Raw almonds
# ...                          ...                                          ...
# 416520 2021-05-23 09:05:43+00:00                                Pain d'épices
# 416522 2019-03-09 16:55:13+00:00                                     pelardon
# 416523 2016-01-03 20:00:15+00:00                    Roussette du Bugey (2011)
# 416528 2021-05-03 05:31:46+00:00                      Casa Mayor Frutos Secos
# 416546 2019-11-03 09:45:23+00:00                                  cup noodles
#
#                                                            generic_name  \
# 32                                                  Mélange Fruits Secs
# 185                                                                <NA>
# 186     Pasta de sémola de trigo duro adicionada con vitaminas y hierro
# 190                                                                <NA>
# 253                                                                <NA>
# ...                                                                 ...
# 416520                                                             <NA>
# 416522                                                             <NA>
# 416523                                              Vins blanc du Bugey
# 416528                                                             <NA>
# 416546                                                             <NA>
#
#        quantity           packaging                 brands  ... sodium_100g  \
# 32        125 g              Sachet  Les Accents du Soleil  ...     0.01700
# 185       32 oz                <NA>   Wilkins Rogers Mills  ...     0.00000
# 186       200 g   Bolsa de plastico                 Yemina  ...     0.00508
# 190        <NA>                <NA>                Emerald  ...     0.00000
# 253        8 oz                <NA>           Simple Truth  ...     0.00000
# ...         ...                 ...                    ...  ...         ...
# 416520    300 g           plastique  Léa Nature Jardin Bio  ...     0.15600
# 416522        6                   4   delices des cevennes  ...     0.40000
# 416523   750 ml  Bouteille en verre     Roussette du Bugey  ...         NaN
# 416528    250 g              Sachet                  Damel  ...         NaN
# 416546      65g           plastique                 nissin  ...     0.40000
#
#        alcohol_100g vitamin-a_100g vitamin-c_100g vitamin-b1_100g  \
# 32              NaN            NaN            NaN             NaN
# 185             NaN            NaN            NaN        0.000333
# 186             NaN            NaN            NaN       62.500000
# 190             NaN            0.0            0.0             NaN
# 253             NaN            NaN            NaN             NaN
# ...             ...            ...            ...             ...
# 416520          NaN            NaN            NaN             NaN
# 416522          NaN            NaN            NaN             NaN
# 416523         12.0            NaN            NaN             NaN
# 416528          NaN            NaN            NaN             NaN
# 416546          0.0            NaN            NaN             NaN
#
#        potassium_100g calcium_100g iron_100g magnesium_100g  \
# 32                NaN          NaN       NaN            NaN
# 185             0.233          NaN   0.00300            NaN
# 186               NaN          NaN   0.00450            NaN
# 190             0.743        0.286   0.00343            NaN
# 253             0.733        0.267   0.00333            NaN
# ...               ...          ...       ...            ...
# 416520            NaN          NaN       NaN            NaN
# 416522            NaN          NaN       NaN            NaN
# 416523            NaN          NaN       NaN            NaN
# 416528            NaN          NaN       NaN            NaN
# 416546            NaN          NaN       NaN            NaN
#
#        nutrition-score-fr_100g
# 32                        -5.0
# 185                       -3.0
# 186                       -6.0
# 190                       -5.0
# 253                       -5.0
# ...                        ...
# 416520                     NaN
# 416522                     NaN
# 416523                     NaN
# 416528                     NaN
# 416546                     NaN
#
# [416552 rows x 66 columns]

# %% [markdown]
# Let us check the first 20 entries.

# %%
df_sort_nsgrade_novagroup[["nutriscore_grade", "nova_group"]].head(20)
# Out:
#     nutriscore_grade nova_group
# 32                 a          1
# 185                a          1
# 186                a          1
# 190                a          1
# 253                a          1
# 270                a          1
# 274                a          1
# 323                a          1
# 341                a          1
# 349                a          1
# 350                a          1
# 364                a          1
# 376                a          1
# 377                a          1
# 382                a          1
# 388                a          1
# 393                a          1
# 409                a          1
# 411                a          1
# 417                a          1

# %% [markdown]
# Products with nutriscore_grade 'a' and nova_group '1' appear first.

# %% [markdown]
# ### Working with dates
#
# pandas has a specific data type for dates. You can explicitly ask pandas to use this type for specific columns, either during `read_csv` or after (as I did in `load_off`), see the [pandas intro tutorial 09](https://pandas.pydata.org/docs/getting_started/intro_tutorials/09_timeseries.html).
#
# This specific data type makes it easy to filter entries by the month of their creation, to know what day of the week an entry was created, or to sort entries by their date of creation.
#
# Sort entries by their date of creation.

# %%
df_sort_created = df.sort_values(by="created_datetime")
df_sort_created
# Out:
#                  code  \
# 193468  3760029248001
# 47317   3029330062806
# 94007   3257980112590
# 44679   3017760038409
# 61192   3160181210524
# ...               ...
# 303660  7501088102776
# 301860  7501003302069
# 301857  7501003301895
# 301876  7501003311429
# 302339  7501020308389
#
#                                                                                                                   url  \
# 193468  http://world-en.openfoodfacts.org/product/3760029248001/caramels-tendres-au-beurre-sale-au-sel-de-guerande...
# 47317                 http://world-en.openfoodfacts.org/product/3029330062806/jacquet-les-bouchees-creatives-a-garnir
# 94007                           http://world-en.openfoodfacts.org/product/3257980112590/boudoirs-aux-oeufs-frais-cora
# 44679                             http://world-en.openfoodfacts.org/product/3017760038409/lulu-la-barquette-fraise-lu
# 61192                           http://world-en.openfoodfacts.org/product/3160181210524/cookies-tout-chocolat-biocoop
# ...                                                                                                               ...
# 303660                                          http://world-en.openfoodfacts.org/product/7501088102776/zataar-terana
# 301860                              http://world-en.openfoodfacts.org/product/7501003302069/hojas-de-laurel-mccormick
# 301857                                 http://world-en.openfoodfacts.org/product/7501003301895/ajo-en-polvo-mccormick
# 301876                                      http://world-en.openfoodfacts.org/product/7501003311429/oregano-mccormick
# 302339                                     http://world-en.openfoodfacts.org/product/7501020308389/paprika-catarino-s
#
#               creator          created_datetime    last_modified_datetime  \
# 193468       stephane 2012-01-31 14:43:58+00:00 2018-08-30 21:14:54+00:00
# 47317        stephane 2012-02-09 10:34:56+00:00 2016-12-23 16:38:19+00:00
# 94007        marianne 2012-02-11 14:51:07+00:00 2021-02-22 22:39:03+00:00
# 44679        marianne 2012-02-11 15:07:23+00:00 2021-06-23 08:00:58+00:00
# 61192        stephane 2012-02-11 18:51:58+00:00 2019-08-23 19:57:37+00:00
# ...               ...                       ...                       ...
# 303660  ana-v-mancera 2021-08-15 23:53:03+00:00 2021-08-15 23:58:07+00:00
# 301860  ana-v-mancera 2021-08-15 23:59:07+00:00 2021-08-16 00:03:26+00:00
# 301857  ana-v-mancera 2021-08-16 00:10:25+00:00 2021-08-16 00:11:20+00:00
# 301876  ana-v-mancera 2021-08-16 00:11:58+00:00 2021-08-16 00:14:52+00:00
# 302339  ana-v-mancera 2021-08-16 00:20:59+00:00 2021-08-16 00:22:45+00:00
#
#                                               product_name  \
# 193468  Caramels tendres au beurre salé au sel de Guérande
# 47317              Jacquet Les bouchées créatives à garnir
# 94007                              Boudoirs aux œufs frais
# 44679                             Lulu La Barquette Fraise
# 61192                        Cookies tout chocolat Biocoop
# ...                                                    ...
# 303660                                              Zataar
# 301860                                     Hojas de Laurel
# 301857                                        Ajo en polvo
# 301876                                             Orégano
# 302339                                             Paprika
#
#                                                     generic_name quantity  \
# 193468  Caramels au beurre salé et à la fleur de sel de Guérande    100 g
# 47317                      Supports en pâte cuite prêts à garnir     54 g
# 94007                                 30 Boudoirs aux œufs frais    175 g
# 44679                        Génoise garnie à la purée de fraise    120 g
# 61192                                        Cookies au chocolat    200 g
# ...                                                          ...      ...
# 303660                                                      <NA>     65 g
# 301860                                                      <NA>     10 g
# 301857                                                      <NA>     77 g
# 301876                                                      <NA>     23 g
# 302339                                                      <NA>     55 g
#
#                                packaging        brands  ... sodium_100g  \
# 193468                      Boite,Carton    Carabreizh  ...     0.68000
# 47317                       Boite carton       Jacquet  ...     0.70104
# 94007                       Boîte,Carton          Cora  ...     0.03600
# 44679            Paquet, Carton, produkt  LU, Mondelez  ...     0.03600
# 61192                       Boîte,Carton       Biocoop  ...     0.15240
# ...                                  ...           ...  ...         ...
# 303660  glass jar,metal lid,plastic wrap        Terana  ...     0.64100
# 301860           plastic jar,plastic lid     McCormick  ...         NaN
# 301857           plastic jar,plastic lid     McCormick  ...         NaN
# 301876           plastic jar,plastic lid     McCormick  ...         NaN
# 302339           plastic jar,plastic lid    Catarino's  ...         NaN
#
#        alcohol_100g vitamin-a_100g vitamin-c_100g vitamin-b1_100g  \
# 193468          NaN            NaN            NaN             NaN
# 47317           NaN            NaN            NaN             NaN
# 94007           NaN            NaN            NaN             NaN
# 44679           NaN            NaN            NaN             NaN
# 61192           NaN            NaN            NaN             NaN
# ...             ...            ...            ...             ...
# 303660          NaN            NaN            NaN             NaN
# 301860          NaN            NaN            NaN             NaN
# 301857          NaN            NaN            NaN             NaN
# 301876          NaN            NaN            NaN             NaN
# 302339          NaN            NaN            NaN             NaN
#
#        potassium_100g calcium_100g iron_100g magnesium_100g  \
# 193468            NaN          NaN       NaN            NaN
# 47317             NaN          NaN       NaN            NaN
# 94007             NaN          NaN       NaN            NaN
# 44679             NaN          NaN       NaN            NaN
# 61192             NaN          NaN       NaN            NaN
# ...               ...          ...       ...            ...
# 303660            NaN          NaN       NaN            NaN
# 301860            NaN          NaN       NaN            NaN
# 301857            NaN          NaN       NaN            NaN
# 301876            NaN          NaN       NaN            NaN
# 302339            NaN          NaN       NaN            NaN
#
#        nutrition-score-fr_100g
# 193468                    28.0
# 47317                     10.0
# 94007                     14.0
# 44679                     13.0
# 61192                     19.0
# ...                        ...
# 303660                     NaN
# 301860                     NaN
# 301857                     NaN
# 301876                     NaN
# 302339                     NaN
#
# [416552 rows x 66 columns]

# %% [markdown]
# Let us check that the first and last entries are as expected.

# %%
df_sort_created["created_datetime"].head(10)
# Out:
# 193468   2012-01-31 14:43:58+00:00
# 47317    2012-02-09 10:34:56+00:00
# 94007    2012-02-11 14:51:07+00:00
# 44679    2012-02-11 15:07:23+00:00
# 61192    2012-02-11 18:51:58+00:00
# 330177   2012-02-11 20:46:21+00:00
# 43673    2012-02-11 21:11:15+00:00
# 51065    2012-02-12 08:32:47+00:00
# 309599   2012-02-12 08:51:55+00:00
# 182209   2012-02-12 18:01:45+00:00
# Name: created_datetime, dtype: datetime64[ns, UTC]

# %% [markdown]
# The oldest entries in our dataset date from 2012.

# %%
df_sort_created["created_datetime"].tail(20)
# Out:
# 25990    2021-08-15 18:16:32+00:00
# 34973    2021-08-15 18:21:32+00:00
# 304802   2021-08-15 18:22:09+00:00
# 252695   2021-08-15 19:21:42+00:00
# 165203   2021-08-15 19:33:05+00:00
# 301566   2021-08-15 20:28:57+00:00
# 348023   2021-08-15 20:36:34+00:00
# 304758   2021-08-15 22:51:58+00:00
# 304860   2021-08-15 23:03:04+00:00
# 304185   2021-08-15 23:11:29+00:00
# 303659   2021-08-15 23:18:41+00:00
# 301859   2021-08-15 23:26:01+00:00
# 302076   2021-08-15 23:35:35+00:00
# 303657   2021-08-15 23:43:38+00:00
# 303658   2021-08-15 23:45:45+00:00
# 303660   2021-08-15 23:53:03+00:00
# 301860   2021-08-15 23:59:07+00:00
# 301857   2021-08-16 00:10:25+00:00
# 301876   2021-08-16 00:11:58+00:00
# 302339   2021-08-16 00:20:59+00:00
# Name: created_datetime, dtype: datetime64[ns, UTC]

# %% [markdown]
# The newest entries in our dataset date from 2021-08-15 (when I downloaded the entire dataset).

# %% [markdown]
# ### Working with textual data
#
# pandas provides a number of functions to process text strings, see the [pandas intro tutorial 10](https://pandas.pydata.org/docs/getting_started/intro_tutorials/10_text_data.html).
#
# Use these functions to select all entries whose list of brands contains "Casino" (this operation is case-sensitive, so mind the initial capital letter!).

# %%
df_casino = df[df["brands"].str.contains("Casino")]
df_casino
# Out:
#                  code  \
# 16018   0200298019689
# 16036   0200448052542
# 16220   0202152035750
# 16416   0203339029524
# 16417   0203339040086
# ...               ...
# 380192  8436018994697
# 396266       85975934
# 409394       88830100
# 416434       96963333
# 416545       99911522
#
#                                                                                                 url  \
# 16018          http://world-en.openfoodfacts.org/product/0200298019689/saucisses-de-toulouse-casino
# 16036   http://world-en.openfoodfacts.org/product/0200448052542/poulet-jaune-fermier-du-gers-casino
# 16220     http://world-en.openfoodfacts.org/product/0202152035750/saucisse-de-toulouse-geant-casino
# 16416               http://world-en.openfoodfacts.org/product/0203339029524/filets-de-poulet-casino
# 16417                http://world-en.openfoodfacts.org/product/0203339040086/filet-de-poulet-casino
# ...                                                                                             ...
# 380192   http://world-en.openfoodfacts.org/product/8436018994697/chorizo-fort-l-espagne-des-saveurs
# 396266              http://world-en.openfoodfacts.org/product/85975934/truffe-fantaisie-noir-casino
# 409394        http://world-en.openfoodfacts.org/product/88830100/assortiment-de-petits-cakes-casino
# 416434                  http://world-en.openfoodfacts.org/product/96963333/farine-de-ble-t65-casino
# 416545                         http://world-en.openfoodfacts.org/product/99911522/chipolatas-casino
#
#                            creator          created_datetime  \
# 16018                      kiliweb 2018-01-21 17:34:37+00:00
# 16036                  moon-rabbit 2017-09-30 09:42:14+00:00
# 16220                      kiliweb 2018-01-20 19:41:37+00:00
# 16416                      kiliweb 2019-12-11 10:00:28+00:00
# 16417                      kiliweb 2020-01-01 20:03:40+00:00
# ...                            ...                       ...
# 380192                     kiliweb 2018-01-13 18:30:42+00:00
# 396266                     kiliweb 2018-03-27 11:58:02+00:00
# 409394  openfoodfacts-contributors 2020-01-02 20:05:22+00:00
# 416434                     kiliweb 2018-04-02 09:06:01+00:00
# 416545                     alm1412 2021-07-04 10:30:44+00:00
#
#           last_modified_datetime                  product_name generic_name  \
# 16018  2019-01-11 10:43:03+00:00         Saucisses de toulouse         <NA>
# 16036  2021-04-03 20:16:26+00:00  Poulet jaune fermier du Gers         <NA>
# 16220  2018-12-27 19:57:11+00:00          Saucisse de toulouse         <NA>
# 16416  2020-10-28 15:13:41+00:00              Filets de poulet         <NA>
# 16417  2020-01-18 11:06:56+00:00               Filet de poulet         <NA>
# ...                          ...                           ...          ...
# 380192 2020-04-29 16:22:00+00:00                  Chorizo Fort         <NA>
# 396266 2019-01-13 19:38:41+00:00         Truffe fantaisie noir         <NA>
# 409394 2020-10-11 14:40:48+00:00   Assortiment de petits cakes         <NA>
# 416434 2021-05-01 11:39:21+00:00             Farine de blé T65         <NA>
# 416545 2021-07-04 10:41:08+00:00                    Chipolatas         <NA>
#
#         quantity          packaging                        brands  ...  \
# 16018       <NA>               <NA>                        Casino  ...
# 16036   1,606 kg               <NA>                        Casino  ...
# 16220       <NA>               <NA>                  Geant Casino  ...
# 16416       <NA>               <NA>                        Casino  ...
# 16417       <NA>               <NA>                        Casino  ...
# ...          ...                ...                           ...  ...
# 380192     170 g               <NA>  L’espagne Des Saveurs,Casino  ...
# 396266     150 g               <NA>                        Casino  ...
# 409394     450 g  Busta di plastica                        Casino  ...
# 416434      <NA>               <NA>                        Casino  ...
# 416545         6          barquette                        Casino  ...
#
#        sodium_100g alcohol_100g vitamin-a_100g vitamin-c_100g vitamin-b1_100g  \
# 16018        0.600          NaN            NaN            NaN             NaN
# 16036          NaN          NaN            NaN            NaN             NaN
# 16220        0.600          NaN            NaN            NaN             NaN
# 16416        0.000          NaN            NaN            NaN             NaN
# 16417        0.000          NaN            NaN            NaN             NaN
# ...            ...          ...            ...            ...             ...
# 380192       1.260          NaN            NaN            NaN             NaN
# 396266       0.120          NaN            NaN            NaN             NaN
# 409394       0.277          NaN            NaN            NaN             NaN
# 416434         NaN          NaN            NaN            NaN             NaN
# 416545         NaN          NaN            NaN            NaN             NaN
#
#        potassium_100g calcium_100g iron_100g magnesium_100g  \
# 16018             NaN          NaN       NaN            NaN
# 16036             NaN          NaN       NaN            NaN
# 16220             NaN          NaN       NaN            NaN
# 16416             NaN          NaN       NaN            NaN
# 16417             NaN          NaN       NaN            NaN
# ...               ...          ...       ...            ...
# 380192            NaN          NaN       NaN            NaN
# 396266            NaN          NaN       NaN            NaN
# 409394            NaN          NaN       NaN            NaN
# 416434            NaN          NaN       NaN            NaN
# 416545            NaN          NaN       NaN            NaN
#
#        nutrition-score-fr_100g
# 16018                     18.0
# 16036                      NaN
# 16220                     18.0
# 16416                      NaN
# 16417                      NaN
# ...                        ...
# 380192                    24.0
# 396266                    27.0
# 409394                    27.0
# 416434                     NaN
# 416545                     NaN
#
# [4434 rows x 66 columns]

# %% [markdown]
# You should get 4434 products whose brands contains "Casino".

# %% [markdown]
# ### Wrapping it all together
#
# Select all the products that are in the category for spreads and store this subset in a variable `df_spreads`.

# %% [markdown]
# > **HINT** If you can't find the right pattern to look for, take a peak at the spelling of the categories: Print the content of the column and browse through the values until you find a suitable value.

# %%
df_spreads = df[df["categories_en"].str.contains("Spreads")].copy()
df_spreads
# Out:
#                  code  \
# 0       0000101209159
# 57      0007700026200
# 172     0009800800254
# 173     0009800801107
# 174     0009800892204
# ...               ...
# 416493       97929352
# 416515  9900010011557
# 416519  9900634104376
# 416531  9935010000003
# 416534       99440084
#
#                                                                                                                   url  \
# 0       http://world-en.openfoodfacts.org/product/0000101209159/veritable-pate-a-tartiner-noisettes-chocolat-noir-...
# 57                                   http://world-en.openfoodfacts.org/product/0007700026200/miel-les-ruchers-du-born
# 172                        http://world-en.openfoodfacts.org/product/0009800800254/hazelnut-spread-with-cocoa-ferrero
# 173      http://world-en.openfoodfacts.org/product/0009800801107/ferrero-nutella-hazelnut-spread-with-cocoa-mini-cups
# 174                http://world-en.openfoodfacts.org/product/0009800892204/ferrero-nutella-hazelnut-spread-with-cocoa
# ...                                                                                                               ...
# 416493                        http://world-en.openfoodfacts.org/product/97929352/nusco-dark-chocolate-spread-brinkers
# 416515                            http://world-en.openfoodfacts.org/product/9900010011557/miel-de-camargue-l-boulaire
# 416519                   http://world-en.openfoodfacts.org/product/9900634104376/ceba-caramel-litzada-ametller-origen
# 416531                             http://world-en.openfoodfacts.org/product/9935010000003/rillette-d-oie-sans-marque
# 416534                 http://world-en.openfoodfacts.org/product/99440084/confiture-de-cerises-les-comtes-de-provence
#
#                            creator          created_datetime  \
# 0                          kiliweb 2018-02-22 10:56:57+00:00
# 57                         kiliweb 2019-12-08 10:17:00+00:00
# 172                usda-ndb-import 2017-03-09 14:51:12+00:00
# 173                         bdwyer 2015-07-26 00:50:59+00:00
# 174     openfoodfacts-contributors 2013-07-02 14:14:24+00:00
# ...                            ...                       ...
# 416493                     kiliweb 2019-08-03 08:28:20+00:00
# 416515                    jeanbono 2013-08-06 08:49:57+00:00
# 416519                     kiliweb 2020-08-25 10:53:57+00:00
# 416531                    sebleouf 2015-10-31 12:07:09+00:00
# 416534                     kiliweb 2018-12-14 19:03:37+00:00
#
#           last_modified_datetime  \
# 0      2020-01-18 19:26:31+00:00
# 57     2019-12-08 12:50:23+00:00
# 172    2020-11-08 07:51:39+00:00
# 173    2020-04-22 18:33:03+00:00
# 174    2021-07-18 17:18:36+00:00
# ...                          ...
# 416493 2020-05-31 10:31:02+00:00
# 416515 2017-09-06 11:54:00+00:00
# 416519 2020-10-25 12:42:53+00:00
# 416531 2015-11-01 11:20:39+00:00
# 416534 2021-05-24 07:22:54+00:00
#
#                                                   product_name  \
# 0            Véritable pâte à tartiner noisettes chocolat noir
# 57                                                        Miel
# 172                                 Hazelnut spread with cocoa
# 173     Ferrero, nutella, hazelnut spread with cocoa mini cups
# 174               Ferrero, nutella, hazelnut spread with cocoa
# ...                                                        ...
# 416493                             Nusco Dark chocolate spread
# 416515                                        Miel de Camargue
# 416519                                    Ceba Caramel•litzada
# 416531                                          Rillette d'oie
# 416534                                    Confiture de cerises
#
#                                   generic_name                       quantity  \
# 0                                         <NA>                          350 g
# 57                                        <NA>                           <NA>
# 172                                       <NA>                           <NA>
# 173     Hazelnut Spread with Skim Milk & Cocoa  10 MINI CUPS - 5.2 OZ (150 g)
# 174                                       <NA>                           1 kg
# ...                                        ...                            ...
# 416493                                    <NA>                           <NA>
# 416515                                    Miel                          250 g
# 416519                                    <NA>                           <NA>
# 416531                                    <NA>                          180 g
# 416534                                    <NA>                           <NA>
#
#           packaging                                  brands  ... sodium_100g  \
# 0              <NA>                                 Bovetti  ...       0.004
# 57             <NA>                     Les ruchers du Born  ...       0.000
# 172            <NA>  Ferrero,  Ferrero U.S.A.  Incorporated  ...       0.041
# 173             Box                         Nutella,Ferrero  ...       0.050
# 174             Pot                         Ferrero,Nutella  ...       0.041
# ...             ...                                     ...  ...         ...
# 416493         <NA>                                Brinkers  ...       0.008
# 416515  Bocal,Verre                             L. Boulaire  ...         NaN
# 416519         <NA>                         ametller origen  ...       0.216
# 416531    Pot,Verre                   Sans marque,D.Lambert  ...         NaN
# 416534         <NA>                  Les Comtes de Provence  ...       0.032
#
#        alcohol_100g vitamin-a_100g vitamin-c_100g vitamin-b1_100g  \
# 0               NaN            NaN            NaN             NaN
# 57              NaN            NaN            NaN             NaN
# 172             NaN            0.0            0.0             NaN
# 173             NaN            0.0            0.0             NaN
# 174             NaN            0.0            0.0             NaN
# ...             ...            ...            ...             ...
# 416493          NaN            NaN            NaN             NaN
# 416515          NaN            NaN            NaN             NaN
# 416519          NaN            NaN            NaN             NaN
# 416531          NaN            NaN            NaN             NaN
# 416534          NaN            NaN            NaN             NaN
#
#        potassium_100g calcium_100g iron_100g magnesium_100g  \
# 0                 NaN          NaN       NaN            NaN
# 57                NaN          NaN       NaN            NaN
# 172               NaN        0.108   0.00195            NaN
# 173               NaN        0.133   0.00240            NaN
# 174               NaN        0.108   0.00195            NaN
# ...               ...          ...       ...            ...
# 416493            NaN          NaN       NaN            NaN
# 416515            NaN          NaN       NaN            NaN
# 416519            NaN          NaN       NaN            NaN
# 416531            NaN          NaN       NaN            NaN
# 416534            NaN          NaN       NaN            NaN
#
#        nutrition-score-fr_100g
# 0                         23.0
# 57                         NaN
# 172                       18.0
# 173                       17.0
# 174                       18.0
# ...                        ...
# 416493                    20.0
# 416515                     NaN
# 416519                    14.0
# 416531                     NaN
# 416534                    10.0
#
# [25565 rows x 66 columns]

# %% [markdown]
# You should find 25565 spreads.

# %% [markdown]
# For these spreads, compute the means of the nutritional values for :
# * fat,
# * saturated fat,
# * sugars,
# * salt.

# %%
df_spreads[["fat_100g", "saturated-fat_100g", "sugars_100g", "salt_100g"]].mean()
# Out:
# fat_100g              20.955330
# saturated-fat_100g     7.974919
# sugars_100g           29.003056
# salt_100g              0.765626
# dtype: float64

# %% [markdown]
# You should find the mean values :
#
# * fat = 20.96 g,
# * saturated-fat = 7.97 g,
# * sugars = 29g,
# * salt = 0.77g.

# %% [markdown]
# For each of these 4 nutritional values, compute the percentage of difference between each product and the average of its category, and store the computed values as new columns to `df_spreads` (eg. `diff-fat_100g`, `diff-sugars_100g` etc).
#
# Remember that you can find help in the [pandas intro tutorial 05](https://pandas.pydata.org/docs/getting_started/intro_tutorials/05_add_columns.html) and [pandas tutorial 06](https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/06_calculate_statistics.html#min-tut-06-stats).

# %%
df_spreads["diff-fat_100g"] = 100 * (df_spreads["fat_100g"] - df_spreads["fat_100g"].mean()) / df_spreads["fat_100g"].mean()
df_spreads["diff-fat_100g"]
# Out:
# 0         129.058667
# 57               NaN
# 172        54.757762
# 173        43.161667
# 174        54.757762
#              ...
# 416493    105.198389
# 416515           NaN
# 416519    -97.613972
# 416531           NaN
# 416534   -100.000000
# Name: diff-fat_100g, Length: 25565, dtype: float64

# %%
df_spreads["diff-saturated-fat_100g"] = 100 * (df_spreads["saturated-fat_100g"] - df_spreads["saturated-fat_100g"].mean()) / df_spreads["saturated-fat_100g"].mean()
df_spreads["diff-sugars_100g"] = 100 * (df_spreads["sugars_100g"] - df_spreads["sugars_100g"].mean()) / df_spreads["sugars_100g"].mean()
df_spreads["diff-salt_100g"] = 100 * (df_spreads["salt_100g"] - df_spreads["salt_100g"].mean()) / df_spreads["salt_100g"].mean()

# %% [markdown]
# Note that these values differ from what the OpenFoodFacts website displays when you look at the nutritional values of a product from this category, eg. [Coconut Spread - premium Srikaya - Hey Boo - 227 g](https://world.openfoodfacts.org/product/0608938316165/coconut-spread-premium-srikaya-hey-boo).

# %%
df_spreads[df_spreads['code'] == '0608938316165']['diff-fat_100g']
# Out:
# 20958    0.213167
# Name: diff-fat_100g, dtype: float64

# %% [markdown]
# This product contains barely 0.2% more fat than the average spreads in our subset, but 17% more than the average spreads in the entire OpenFoodFacts dataset (as displayed on the OFF website).

# %% [markdown]
# This is because the OpenFoodFacts website uses its entire dataset, whereas we are working on a filtered subset of "reasonably complete" product entries prepared beforehand to keep only products with :
#
# * a non-ambiguous barcode in the EAN-8 or EAN-13 formats ;
# * a product name,
# * brands,
# * an image URL for the product ;
# * a category ;
# * basic nutritional values.

# %% [markdown]
# It seems that, in this "resonably complete" subset, spreads contain more fat on average than in the whole OpenFoodFacts dataset.
#
# Is the entire OpenFoodFacts dataset closer to the reality of what is on the shelves of supermarkets ?
# Is our subset more faithful globally ? Is it more faithful to the consumer market in certain countries, eg. France and Spain ?
#
# These questions raise the more general problem of [Selection bias](https://en.wikipedia.org/wiki/Selection_bias) that lies behind every data analysis and use of dataset for eg. artificial intelligence systems.

# %% [markdown]
# ## Bonus exercise : Traffic light labelling
#
# The [traffic light labelling system](https://www.nutrition.org.uk/healthyliving/helpingyoueatwell/324-labels.html?start=3) is used on the [OpenFoodFacts website (French)](https://fr.openfoodfacts.org/reperes-nutritionnels) to display colorful, easier to grasp information on 4 nutritional values with a color code :
#
# * fat,
# * saturated fat,
# * sugars,
# * salt.

# %% [markdown]
# The OpenFoodFacts dataset does not contain these indicators, but you can recompute them from the [reference table](https://www.nutrition.org.uk/media/er5n0c3s/capture.png).

# %% [markdown]
# Add 4 columns to the dataset, one for each of the 4 relevant nutritional values, that will contain the  (low, medium, high) or color (green, yellow, red) of the traffic light.

# %% [markdown]
# > **HINT** You can simplify the exercise and express all conditions on the values per 100g (ignoring the rightmost column of the table where thresholds are expressed per portion).

# %%
# for fat_100g
df["tl_fat"] = "unknown"
df.loc[df["fat_100g"] <= 3, "tl_fat"] = "green"
df.loc[(df["fat_100g"] > 3) & (df["fat_100g"] <= 17.5), "tl_fat"] = "amber"
df.loc[(df["fat_100g"] > 17.5), "tl_fat"] = "red"

# %% [markdown]
# Let us check that the traffic lights for fat are as wanted.

# %%
df[["fat_100g", "tl_fat"]].head(10)
# Out:
#    fat_100g   tl_fat
# 0      48.0      red
# 1      34.7      red
# 2       1.0    green
# 3       1.0    green
# 4       0.5    green
# 5       4.6    amber
# 6       4.6    amber
# 7       4.6    amber
# 8       6.3    amber
# 9       NaN  unknown

# %% [markdown]
# Now you can define the traffic lights for the 3 remaining nutritional values.

# %%
# for saturated-fat_100g
df["tl_saturated-fat"] = "unknown"
df.loc[df["saturated-fat_100g"] <= 1.5, "tl_saturated-fat"] = "green"
df.loc[(df["saturated-fat_100g"] > 1.5) & (df["saturated-fat_100g"] <= 5), "tl_saturated-fat"] = "amber"
df.loc[(df["saturated-fat_100g"] > 5), "tl_saturated-fat"] = "red"
# for sugar_100g
df["tl_sugars"] = "unknown"
df.loc[df["sugars_100g"] <= 5, "tl_sugars"] = "green"
df.loc[(df["sugars_100g"] > 5) & (df["sugars_100g"] <= 22.5), "tl_sugars"] = "amber"
df.loc[(df["sugars_100g"] > 22.5), "tl_sugars"] = "red"
# for salt_100g
df["tl_salt"] = "unknown"
df.loc[df["salt_100g"] <= 0.3, "tl_salt"] = "green"
df.loc[(df["salt_100g"] > 0.3) & (df["salt_100g"] <= 1.5), "tl_salt"] = "amber"
df.loc[(df["salt_100g"] > 1.5), "tl_salt"] = "red"

# %% [markdown]
# We can display the traffic lights for the first 10 products, and compare with what the Open Food Facts website displays (remember: you can retrieve URLs from the column `url`).

# %%
df[["url", "tl_fat", "tl_saturated-fat", "tl_sugars", "tl_salt"]].head(10)
# Out:
#                                                                                                              url  \
# 0  http://world-en.openfoodfacts.org/product/0000101209159/veritable-pate-a-tartiner-noisettes-chocolat-noir-...
# 1                        http://world-en.openfoodfacts.org/product/0000159487776/milkyway-magic-stars-chocolates
# 2  http://world-en.openfoodfacts.org/product/0000204286484/mehrkomponeneten-protein-90-c6-haselnuss-allfitnes...
# 3  http://world-en.openfoodfacts.org/product/0000250632969/mehrkomponeneten-protein-90-c6-banane-allfitnessfa...
# 4        http://world-en.openfoodfacts.org/product/0000460938714/100-soja-protein-haselnuss-allfitnessfactory-de
# 5    http://world-en.openfoodfacts.org/product/0000470322800/whey-protein-aus-molke-vanilla-allfitnessfactory-de
# 6  http://world-en.openfoodfacts.org/product/0000501050603/whey-protein-aus-molke-1000-gramm-vanilla-allfitne...
# 7  http://world-en.openfoodfacts.org/product/0000526938306/whey-protein-aus-molke-500-gramm-vanilla-allfitnes...
# 8                         http://world-en.openfoodfacts.org/product/0000554004509/pain-de-mie-sans-gluten-genius
# 9                        http://world-en.openfoodfacts.org/product/0000606009841/beignets-framboises-intermarche
#
#     tl_fat tl_saturated-fat tl_sugars  tl_salt
# 0      red              red       red    green
# 1      red          unknown       red  unknown
# 2    green          unknown   unknown  unknown
# 3    green          unknown   unknown  unknown
# 4    green          unknown   unknown  unknown
# 5    amber          unknown     amber    amber
# 6    amber          unknown     amber    amber
# 7    amber          unknown     amber    amber
# 8    amber            green     green    amber
# 9  unknown            amber     amber    amber

# %% [markdown]
# ## To go further
#
# ### Python for data science
#
# * [Programming in Python for Data Science](https://prog-learn.mds.ubc.ca/en/)
# * [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/)
